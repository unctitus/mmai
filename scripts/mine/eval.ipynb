# %% [markdown]
# ### Define Names of Policies and Tasks

# %% [markdown]
# eval_results
#     policies
#         abstract_task_level (meaningless)
#             robot_controller (meaningless)
#                 task-level (contains urdf in the name)
#                     trial-level
#                         video

# %%
policies = ["rt_1_tf_trained_for_000400120",
            "rt_1_tf_trained_for_000058240",
            "rt_1_x_tf_trained_for_002272480_step",
            "rt_1_tf_trained_for_000001120",
            "octo-base",
            "openvla-7b"
            ]

policies_short = ["rt-1-converged",
            "rt-1-15pct",
            "rt-1-x",
            "rt-1-begin",
            "octo-base",
            "openvla-7b"
            ]

urdf_versions = ["recolor_cabinet_visual_matching_1", 
                 "recolor_tabletop_visual_matching_1", 
                 "recolor_tabletop_visual_matching_2", 
                 "None"
                 ]

drawer_tasks = ["OpenTopDrawerCustomInScene-v0",
                "OpenMiddleDrawerCustomInScene-v0",
                "OpenBottomDrawerCustomInScene-v0",
                "CloseTopDrawerCustomInScene-v0",
                "CloseMiddleDrawerCustomInScene-v0",
                "CloseBottomDrawerCustomInScene-v0"
                ]

pick_tasks = ["GraspSingleOpenedCokeCanInScene-v0"]

move_tasks = ["MoveNearGoogleBakedTexInScene-v0"]

place_tasks = ["PlaceIntoClosedTopDrawerCustomInScene-v0"]

move_to_number_tasks = ["PutOnNumberGoogleInScene-v0", 
                        "PutOnNumberSumGoogleInScene-v0",
                        "PutOnNumberMultGoogleInScene-v0",
                        "PutOnNumberSmallestGoogleInScene-v0"]

orientations = ["lr_switch_True","laid_vertically_True", "upright_True"]

drawer_real_success = {
        "open": {
          #  "rt-2-x": 0.333,
            "rt-1-converged": 0.815,
            "rt-1-15pct": 0.704,
            "rt-1-x": 0.519,
            "rt-1-begin": 0.000,
            "octo-base": 0.148,
        },
        "close": {
          #   "rt-2-x": 0.630,
            "rt-1-converged": 0.926,
            "rt-1-15pct": 0.889,
            "rt-1-x": 0.741,
            "rt-1-begin": 0.000,
            "octo-base": 0.519,
        },
    }


num_trials_per_real_task={
    "google_robot_open_drawer" : 27,
    "google_robot_close_drawer" : 27,
    "google_robot_drawer_avg" : 54, # 9 robot locations x 3 shelves (top, middle, bottom) x 2 close/open
    "google_robot_pick_coke_can_horizontally_laying" : 25,
    "google_robot_pick_coke_can_vertically_laying" : 25,
    "google_robot_pick_coke_can_standing" : 25,
    "google_robot_pick_coke_can" : 75, # 25 locations of coke can x 3 coke can orientation (vertically/horizontally laying, standing)
    "google_robot_move_near" : 60, # 5 triplets of objects * 6 combination * 2 triangle patterns
    "google_robot_place_apple_in_closed_top_drawer" : 27, # 3 robot locations x 9 apple locations
}

# RT-2-X checkpoint not released by Googe, so commented out
REAL_PERF = {    
    "google_robot_pick_coke_can": {
        #"rt-2-x": 0.907,
        "rt-1-converged": 0.853,
        "rt-1-15pct": 0.920,
        "rt-1-x": 0.760,
        "rt-1-begin": 0.133,
        "octo-base": 0.293,
    },
     "google_robot_pick_coke_can_horizontally_laying": {
        #"rt-2-x": 0.920,
        "rt-1-converged": 0.960,
        "rt-1-15pct": 1,
        "rt-1-x": 0.880,
        "rt-1-begin": 0.200,
        "octo-base": 0.440,
    },
     "google_robot_pick_coke_can_vertically_laying": {
        #"rt-2-x": 0.8,
        "rt-1-converged": 0.880,
        "rt-1-15pct": 0.960,
        "rt-1-x": 0.560,
        "rt-1-begin": 0,
        "octo-base": 0.200,
    },
     "google_robot_pick_coke_can_standing": {
        #"rt-2-x": 1,
        "rt-1-converged": 0.720,
        "rt-1-15pct": 0.800,
        "rt-1-x": 0.840,
        "rt-1-begin": 0.200,
        "octo-base": 0.240,
    },
    "google_robot_move_near": {
       # "rt-2-x": 0.733,
        "rt-1-converged": 0.633,
        "rt-1-15pct": 0.583,
        "rt-1-x": 0.450,
        "rt-1-begin": 0.017,
        "octo-base": 0.350,
    },
    "google_robot_drawer_avg": {
      'rt-1-converged': 0.870, 
      'rt-1-15pct': 0.796, 
      'rt-1-x': 0.630, 
      'rt-1-begin': 0.000, 
      'octo-base': 0.333
    },
    "google_robot_open_drawer": {
       # "rt-2-x": 0.333,
        "rt-1-converged": 0.815,
        "rt-1-15pct": 0.704,
        "rt-1-x": 0.519,
        "rt-1-begin": 0.000,
        "octo-base": 0.148,
    },
    "google_robot_close_drawer": {
        #"rt-2-x": 0.630,
        "rt-1-converged": 0.926,
        "rt-1-15pct": 0.889,
        "rt-1-x": 0.741,
        "rt-1-begin": 0.000,
        "octo-base": 0.519,
    },
    "google_robot_place_apple_in_closed_top_drawer": {
        #"rt-2-x": 0.074,
        "rt-1-converged": 0.185,
        "rt-1-15pct": 0.185,
        "rt-1-x": 0.407,
        "rt-1-begin": 0.000,
        "octo-base": 0.000,
    },
    "widowx_spoon_on_towel": {
        "rt-1-x": 0.000,
        "octo-base": 0.333,
        "octo-small": 0.417,
    },
    "widowx_carrot_on_plate": {
        "rt-1-x": 0.000,
        "octo-base": 0.250,
        "octo-small": 0.083,
    },
    "widowx_stack_cube": {
        "rt-1-x": 0.000,
        "octo-base": 0.000,
        "octo-small": 0.125,
    },
    "widowx_put_eggplant_in_basket": {
        "rt-1-x": 0.000,
        "octo-base": 0.250,
        "octo-small": 0.400,
    },
}

# %%
#Alternatively compute the average for the drawer tasks
# Yields slightly different results then the ones reported in the paper (they round down when .5 in the paper)
# Compute the average for each key by iterating over the keys in "open"
#REAL_PERF["google_robot_drawer_avg"] = {
#    key: (REAL_PERF["google_robot_open_drawer"][key] + REAL_PERF["google_robot_close_drawer"][key]) / 2
#    for key in REAL_PERF["google_robot_open_drawer"]
#}

# %% [markdown]
# ### Print Eval Results

# %%
from rich.tree import Tree
from rich.console import Console
import glob

dir_name = "/work/users/t/i/tis/mmai/results"
filenames = glob.glob(f"{dir_name}/**/*.mp4", recursive=True)

def count_files(filenames, extra_pattern_require):
    filtered_filenames = list(filter(lambda filename: all(
        pattern in filename for pattern in extra_pattern_require), filenames))
    return len(filtered_filenames), filtered_filenames

def add_tree_nodes(branch, levels, extra_pattern):
    # for leaf nodes
    if len(levels) == 1:  
        for item in levels[0]:
            # count the files that match the extra pattern 
            result, _ = count_files(filenames, extra_pattern_require=extra_pattern + [item])
            branch.add(f"{result} {item}")
        return
    # call recursively for the next level
    for item in levels[0]:
        sub_branch = branch.add(item)
        add_tree_nodes(sub_branch, levels[1:], extra_pattern + [item])

def print_overview(levels):
    console = Console()
    tree = Tree("Eval Results")
    add_tree_nodes(tree, levels, [])
    console.print(tree)

# %% [markdown]
# ### Results for New Tasks

# %%
scenes = ["dummy_tabletop1", "dummy_wood_tabletop"]
move_tasks_new = ["MoveNearGoogleBakedTexInSceneNew-v0"]
print_overview([scenes, urdf_versions, pick_tasks, policies, orientations])
print_overview([scenes,urdf_versions, move_tasks_new, policies])
# Out:
# Eval Results
# ├── dummy_tabletop1
# │   ├── recolor_cabinet_visual_matching_1
# │   │   └── GraspSingleOpenedCokeCanInScene-v0
# │   │       ├── rt_1_tf_trained_for_000400120
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── rt_1_tf_trained_for_000058240
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── rt_1_x_tf_trained_for_002272480_step
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── rt_1_tf_trained_for_000001120
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── octo-base
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       └── openvla-7b
# │   │           ├── 25 lr_switch_True
# │   │           ├── 25 laid_vertically_True
# │   │           └── 25 upright_True
# │   ├── recolor_tabletop_visual_matching_1
# │   │   └── GraspSingleOpenedCokeCanInScene-v0
# │   │       ├── rt_1_tf_trained_for_000400120
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── rt_1_tf_trained_for_000058240
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── rt_1_x_tf_trained_for_002272480_step
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── rt_1_tf_trained_for_000001120
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── octo-base
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       └── openvla-7b
# │   │           ├── 25 lr_switch_True
# │   │           ├── 25 laid_vertically_True
# │   │           └── 25 upright_True
# │   ├── recolor_tabletop_visual_matching_2
# │   │   └── GraspSingleOpenedCokeCanInScene-v0
# │   │       ├── rt_1_tf_trained_for_000400120
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── rt_1_tf_trained_for_000058240
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── rt_1_x_tf_trained_for_002272480_step
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── rt_1_tf_trained_for_000001120
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── octo-base
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       └── openvla-7b
# │   │           ├── 25 lr_switch_True
# │   │           ├── 25 laid_vertically_True
# │   │           └── 25 upright_True
# │   └── None
# │       └── GraspSingleOpenedCokeCanInScene-v0
# │           ├── rt_1_tf_trained_for_000400120
# │           │   ├── 25 lr_switch_True
# │           │   ├── 25 laid_vertically_True
# │           │   └── 25 upright_True
# │           ├── rt_1_tf_trained_for_000058240
# │           │   ├── 25 lr_switch_True
# │           │   ├── 25 laid_vertically_True
# │           │   └── 25 upright_True
# │           ├── rt_1_x_tf_trained_for_002272480_step
# │           │   ├── 25 lr_switch_True
# │           │   ├── 25 laid_vertically_True
# │           │   └── 25 upright_True
# │           ├── rt_1_tf_trained_for_000001120
# │           │   ├── 25 lr_switch_True
# │           │   ├── 25 laid_vertically_True
# │           │   └── 25 upright_True
# │           ├── octo-base
# │           │   ├── 25 lr_switch_True
# │           │   ├── 25 laid_vertically_True
# │           │   └── 25 upright_True
# │           └── openvla-7b
# │               ├── 25 lr_switch_True
# │               ├── 25 laid_vertically_True
# │               └── 25 upright_True
# └── dummy_wood_tabletop
#     ├── recolor_cabinet_visual_matching_1
#     │   └── GraspSingleOpenedCokeCanInScene-v0
#     │       ├── rt_1_tf_trained_for_000400120
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── rt_1_tf_trained_for_000058240
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── rt_1_x_tf_trained_for_002272480_step
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── rt_1_tf_trained_for_000001120
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── octo-base
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       └── openvla-7b
#     │           ├── 25 lr_switch_True
#     │           ├── 25 laid_vertically_True
#     │           └── 25 upright_True
#     ├── recolor_tabletop_visual_matching_1
#     │   └── GraspSingleOpenedCokeCanInScene-v0
#     │       ├── rt_1_tf_trained_for_000400120
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── rt_1_tf_trained_for_000058240
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── rt_1_x_tf_trained_for_002272480_step
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── rt_1_tf_trained_for_000001120
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── octo-base
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       └── openvla-7b
#     │           ├── 25 lr_switch_True
#     │           ├── 25 laid_vertically_True
#     │           └── 25 upright_True
#     ├── recolor_tabletop_visual_matching_2
#     │   └── GraspSingleOpenedCokeCanInScene-v0
#     │       ├── rt_1_tf_trained_for_000400120
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── rt_1_tf_trained_for_000058240
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── rt_1_x_tf_trained_for_002272480_step
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── rt_1_tf_trained_for_000001120
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── octo-base
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       └── openvla-7b
#     │           ├── 25 lr_switch_True
#     │           ├── 25 laid_vertically_True
#     │           └── 25 upright_True
#     └── None
#         └── GraspSingleOpenedCokeCanInScene-v0
#             ├── rt_1_tf_trained_for_000400120
#             │   ├── 25 lr_switch_True
#             │   ├── 25 laid_vertically_True
#             │   └── 25 upright_True
#             ├── rt_1_tf_trained_for_000058240
#             │   ├── 25 lr_switch_True
#             │   ├── 25 laid_vertically_True
#             │   └── 25 upright_True
#             ├── rt_1_x_tf_trained_for_002272480_step
#             │   ├── 25 lr_switch_True
#             │   ├── 25 laid_vertically_True
#             │   └── 25 upright_True
#             ├── rt_1_tf_trained_for_000001120
#             │   ├── 25 lr_switch_True
#             │   ├── 25 laid_vertically_True
#             │   └── 25 upright_True
#             ├── octo-base
#             │   ├── 25 lr_switch_True
#             │   ├── 25 laid_vertically_True
#             │   └── 25 upright_True
#             └── openvla-7b
#                 ├── 25 lr_switch_True
#                 ├── 25 laid_vertically_True
#                 └── 25 upright_True
# Eval Results
# ├── dummy_tabletop1
# │   ├── recolor_cabinet_visual_matching_1
# │   │   └── MoveNearGoogleBakedTexInSceneNew-v0
# │   │       ├── 60 rt_1_tf_trained_for_000400120
# │   │       ├── 60 rt_1_tf_trained_for_000058240
# │   │       ├── 60 rt_1_x_tf_trained_for_002272480_step
# │   │       ├── 60 rt_1_tf_trained_for_000001120
# │   │       ├── 60 octo-base
# │   │       └── 50 openvla-7b
# │   ├── recolor_tabletop_visual_matching_1
# │   │   └── MoveNearGoogleBakedTexInSceneNew-v0
# │   │       ├── 60 rt_1_tf_trained_for_000400120
# │   │       ├── 60 rt_1_tf_trained_for_000058240
# │   │       ├── 60 rt_1_x_tf_trained_for_002272480_step
# │   │       ├── 60 rt_1_tf_trained_for_000001120
# │   │       ├── 60 octo-base
# │   │       └── 60 openvla-7b
# │   ├── recolor_tabletop_visual_matching_2
# │   │   └── MoveNearGoogleBakedTexInSceneNew-v0
# │   │       ├── 60 rt_1_tf_trained_for_000400120
# │   │       ├── 60 rt_1_tf_trained_for_000058240
# │   │       ├── 60 rt_1_x_tf_trained_for_002272480_step
# │   │       ├── 60 rt_1_tf_trained_for_000001120
# │   │       ├── 60 octo-base
# │   │       └── 50 openvla-7b
# │   └── None
# │       └── MoveNearGoogleBakedTexInSceneNew-v0
# │           ├── 60 rt_1_tf_trained_for_000400120
# │           ├── 60 rt_1_tf_trained_for_000058240
# │           ├── 60 rt_1_x_tf_trained_for_002272480_step
# │           ├── 60 rt_1_tf_trained_for_000001120
# │           ├── 60 octo-base
# │           └── 60 openvla-7b
# └── dummy_wood_tabletop
#     ├── recolor_cabinet_visual_matching_1
#     │   └── MoveNearGoogleBakedTexInSceneNew-v0
#     │       ├── 60 rt_1_tf_trained_for_000400120
#     │       ├── 60 rt_1_tf_trained_for_000058240
#     │       ├── 60 rt_1_x_tf_trained_for_002272480_step
#     │       ├── 60 rt_1_tf_trained_for_000001120
#     │       ├── 60 octo-base
#     │       └── 60 openvla-7b
#     ├── recolor_tabletop_visual_matching_1
#     │   └── MoveNearGoogleBakedTexInSceneNew-v0
#     │       ├── 60 rt_1_tf_trained_for_000400120
#     │       ├── 60 rt_1_tf_trained_for_000058240
#     │       ├── 60 rt_1_x_tf_trained_for_002272480_step
#     │       ├── 60 rt_1_tf_trained_for_000001120
#     │       ├── 60 octo-base
#     │       └── 60 openvla-7b
#     ├── recolor_tabletop_visual_matching_2
#     │   └── MoveNearGoogleBakedTexInSceneNew-v0
#     │       ├── 60 rt_1_tf_trained_for_000400120
#     │       ├── 60 rt_1_tf_trained_for_000058240
#     │       ├── 60 rt_1_x_tf_trained_for_002272480_step
#     │       ├── 60 rt_1_tf_trained_for_000001120
#     │       ├── 60 octo-base
#     │       └── 60 openvla-7b
#     └── None
#         └── MoveNearGoogleBakedTexInSceneNew-v0
#             ├── 60 rt_1_tf_trained_for_000400120
#             ├── 60 rt_1_tf_trained_for_000058240
#             ├── 60 rt_1_x_tf_trained_for_002272480_step
#             ├── 60 rt_1_tf_trained_for_000001120
#             ├── 60 octo-base
#             └── 60 openvla-7b

# %%
print_overview([urdf_versions, move_to_number_tasks, policies])
# Out:
# Eval Results
# ├── recolor_cabinet_visual_matching_1
# │   ├── PutOnNumberGoogleInScene-v0
# │   │   ├── 24 rt_1_tf_trained_for_000400120
# │   │   ├── 24 rt_1_tf_trained_for_000058240
# │   │   ├── 24 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 24 rt_1_tf_trained_for_000001120
# │   │   ├── 24 octo-base
# │   │   └── 24 openvla-7b
# │   ├── PutOnNumberSumGoogleInScene-v0
# │   │   ├── 24 rt_1_tf_trained_for_000400120
# │   │   ├── 24 rt_1_tf_trained_for_000058240
# │   │   ├── 24 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 24 rt_1_tf_trained_for_000001120
# │   │   ├── 24 octo-base
# │   │   └── 8 openvla-7b
# │   ├── PutOnNumberMultGoogleInScene-v0
# │   │   ├── 24 rt_1_tf_trained_for_000400120
# │   │   ├── 24 rt_1_tf_trained_for_000058240
# │   │   ├── 24 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 0 rt_1_tf_trained_for_000001120
# │   │   ├── 24 octo-base
# │   │   └── 8 openvla-7b
# │   └── PutOnNumberSmallestGoogleInScene-v0
# │       ├── 24 rt_1_tf_trained_for_000400120
# │       ├── 24 rt_1_tf_trained_for_000058240
# │       ├── 24 rt_1_x_tf_trained_for_002272480_step
# │       ├── 24 rt_1_tf_trained_for_000001120
# │       ├── 24 octo-base
# │       └── 24 openvla-7b
# ├── recolor_tabletop_visual_matching_1
# │   ├── PutOnNumberGoogleInScene-v0
# │   │   ├── 24 rt_1_tf_trained_for_000400120
# │   │   ├── 24 rt_1_tf_trained_for_000058240
# │   │   ├── 24 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 24 rt_1_tf_trained_for_000001120
# │   │   ├── 24 octo-base
# │   │   └── 24 openvla-7b
# │   ├── PutOnNumberSumGoogleInScene-v0
# │   │   ├── 24 rt_1_tf_trained_for_000400120
# │   │   ├── 24 rt_1_tf_trained_for_000058240
# │   │   ├── 24 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 24 rt_1_tf_trained_for_000001120
# │   │   ├── 24 octo-base
# │   │   └── 8 openvla-7b
# │   ├── PutOnNumberMultGoogleInScene-v0
# │   │   ├── 24 rt_1_tf_trained_for_000400120
# │   │   ├── 24 rt_1_tf_trained_for_000058240
# │   │   ├── 24 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 24 rt_1_tf_trained_for_000001120
# │   │   ├── 24 octo-base
# │   │   └── 8 openvla-7b
# │   └── PutOnNumberSmallestGoogleInScene-v0
# │       ├── 24 rt_1_tf_trained_for_000400120
# │       ├── 24 rt_1_tf_trained_for_000058240
# │       ├── 24 rt_1_x_tf_trained_for_002272480_step
# │       ├── 24 rt_1_tf_trained_for_000001120
# │       ├── 24 octo-base
# │       └── 24 openvla-7b
# ├── recolor_tabletop_visual_matching_2
# │   ├── PutOnNumberGoogleInScene-v0
# │   │   ├── 24 rt_1_tf_trained_for_000400120
# │   │   ├── 24 rt_1_tf_trained_for_000058240
# │   │   ├── 24 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 24 rt_1_tf_trained_for_000001120
# │   │   ├── 24 octo-base
# │   │   └── 24 openvla-7b
# │   ├── PutOnNumberSumGoogleInScene-v0
# │   │   ├── 24 rt_1_tf_trained_for_000400120
# │   │   ├── 24 rt_1_tf_trained_for_000058240
# │   │   ├── 24 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 24 rt_1_tf_trained_for_000001120
# │   │   ├── 24 octo-base
# │   │   └── 8 openvla-7b
# │   ├── PutOnNumberMultGoogleInScene-v0
# │   │   ├── 24 rt_1_tf_trained_for_000400120
# │   │   ├── 24 rt_1_tf_trained_for_000058240
# │   │   ├── 24 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 24 rt_1_tf_trained_for_000001120
# │   │   ├── 24 octo-base
# │   │   └── 8 openvla-7b
# │   └── PutOnNumberSmallestGoogleInScene-v0
# │       ├── 24 rt_1_tf_trained_for_000400120
# │       ├── 24 rt_1_tf_trained_for_000058240
# │       ├── 24 rt_1_x_tf_trained_for_002272480_step
# │       ├── 24 rt_1_tf_trained_for_000001120
# │       ├── 24 octo-base
# │       └── 24 openvla-7b
# └── None
#     ├── PutOnNumberGoogleInScene-v0
#     │   ├── 24 rt_1_tf_trained_for_000400120
#     │   ├── 24 rt_1_tf_trained_for_000058240
#     │   ├── 24 rt_1_x_tf_trained_for_002272480_step
#     │   ├── 24 rt_1_tf_trained_for_000001120
#     │   ├── 24 octo-base
#     │   └── 24 openvla-7b
#     ├── PutOnNumberSumGoogleInScene-v0
#     │   ├── 24 rt_1_tf_trained_for_000400120
#     │   ├── 24 rt_1_tf_trained_for_000058240
#     │   ├── 24 rt_1_x_tf_trained_for_002272480_step
#     │   ├── 24 rt_1_tf_trained_for_000001120
#     │   ├── 24 octo-base
#     │   └── 8 openvla-7b
#     ├── PutOnNumberMultGoogleInScene-v0
#     │   ├── 24 rt_1_tf_trained_for_000400120
#     │   ├── 24 rt_1_tf_trained_for_000058240
#     │   ├── 24 rt_1_x_tf_trained_for_002272480_step
#     │   ├── 24 rt_1_tf_trained_for_000001120
#     │   ├── 24 octo-base
#     │   └── 8 openvla-7b
#     └── PutOnNumberSmallestGoogleInScene-v0
#         ├── 24 rt_1_tf_trained_for_000400120
#         ├── 24 rt_1_tf_trained_for_000058240
#         ├── 24 rt_1_x_tf_trained_for_002272480_step
#         ├── 24 rt_1_tf_trained_for_000001120
#         ├── 24 octo-base
#         └── 24 openvla-7b

# %%
outcome = ["success", "failure"]
print_overview([urdf_versions, drawer_tasks, policies])
#print_overview([policies, drawer_tasks, urdf_versions, outcome])

scenes = ["dummy_tabletop1", "dummy_wood_tabletop"]
print_overview([scenes, urdf_versions, pick_tasks, policies, orientations])

print_overview([urdf_versions, move_tasks, policies])
#move_type = ["moved_correct_obj_False", "moved_correct_obj_True"]
#print_overview([urdf_versions, move_tasks, policies, move_type])

print_overview([urdf_versions, place_tasks, policies])
#robot_position = ["a0", "b0", "c0"]
#print_overview([urdf_versions, place_tasks, policies, robot_position])
# Out:
# Eval Results
# ├── recolor_cabinet_visual_matching_1
# │   ├── OpenTopDrawerCustomInScene-v0
# │   │   ├── 9 rt_1_tf_trained_for_000400120
# │   │   ├── 9 rt_1_tf_trained_for_000058240
# │   │   ├── 9 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 9 rt_1_tf_trained_for_000001120
# │   │   ├── 9 octo-base
# │   │   └── 0 openvla-7b
# │   ├── OpenMiddleDrawerCustomInScene-v0
# │   │   ├── 9 rt_1_tf_trained_for_000400120
# │   │   ├── 9 rt_1_tf_trained_for_000058240
# │   │   ├── 9 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 9 rt_1_tf_trained_for_000001120
# │   │   ├── 9 octo-base
# │   │   └── 0 openvla-7b
# │   ├── OpenBottomDrawerCustomInScene-v0
# │   │   ├── 9 rt_1_tf_trained_for_000400120
# │   │   ├── 9 rt_1_tf_trained_for_000058240
# │   │   ├── 9 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 9 rt_1_tf_trained_for_000001120
# │   │   ├── 9 octo-base
# │   │   └── 0 openvla-7b
# │   ├── CloseTopDrawerCustomInScene-v0
# │   │   ├── 9 rt_1_tf_trained_for_000400120
# │   │   ├── 9 rt_1_tf_trained_for_000058240
# │   │   ├── 9 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 9 rt_1_tf_trained_for_000001120
# │   │   ├── 9 octo-base
# │   │   └── 0 openvla-7b
# │   ├── CloseMiddleDrawerCustomInScene-v0
# │   │   ├── 9 rt_1_tf_trained_for_000400120
# │   │   ├── 9 rt_1_tf_trained_for_000058240
# │   │   ├── 9 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 9 rt_1_tf_trained_for_000001120
# │   │   ├── 9 octo-base
# │   │   └── 0 openvla-7b
# │   └── CloseBottomDrawerCustomInScene-v0
# │       ├── 9 rt_1_tf_trained_for_000400120
# │       ├── 9 rt_1_tf_trained_for_000058240
# │       ├── 9 rt_1_x_tf_trained_for_002272480_step
# │       ├── 9 rt_1_tf_trained_for_000001120
# │       ├── 9 octo-base
# │       └── 0 openvla-7b
# ├── recolor_tabletop_visual_matching_1
# │   ├── OpenTopDrawerCustomInScene-v0
# │   │   ├── 9 rt_1_tf_trained_for_000400120
# │   │   ├── 9 rt_1_tf_trained_for_000058240
# │   │   ├── 9 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 9 rt_1_tf_trained_for_000001120
# │   │   ├── 9 octo-base
# │   │   └── 0 openvla-7b
# │   ├── OpenMiddleDrawerCustomInScene-v0
# │   │   ├── 9 rt_1_tf_trained_for_000400120
# │   │   ├── 9 rt_1_tf_trained_for_000058240
# │   │   ├── 9 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 9 rt_1_tf_trained_for_000001120
# │   │   ├── 9 octo-base
# │   │   └── 0 openvla-7b
# │   ├── OpenBottomDrawerCustomInScene-v0
# │   │   ├── 9 rt_1_tf_trained_for_000400120
# │   │   ├── 9 rt_1_tf_trained_for_000058240
# │   │   ├── 9 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 9 rt_1_tf_trained_for_000001120
# │   │   ├── 9 octo-base
# │   │   └── 0 openvla-7b
# │   ├── CloseTopDrawerCustomInScene-v0
# │   │   ├── 9 rt_1_tf_trained_for_000400120
# │   │   ├── 9 rt_1_tf_trained_for_000058240
# │   │   ├── 9 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 9 rt_1_tf_trained_for_000001120
# │   │   ├── 9 octo-base
# │   │   └── 0 openvla-7b
# │   ├── CloseMiddleDrawerCustomInScene-v0
# │   │   ├── 9 rt_1_tf_trained_for_000400120
# │   │   ├── 9 rt_1_tf_trained_for_000058240
# │   │   ├── 9 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 9 rt_1_tf_trained_for_000001120
# │   │   ├── 9 octo-base
# │   │   └── 0 openvla-7b
# │   └── CloseBottomDrawerCustomInScene-v0
# │       ├── 9 rt_1_tf_trained_for_000400120
# │       ├── 9 rt_1_tf_trained_for_000058240
# │       ├── 9 rt_1_x_tf_trained_for_002272480_step
# │       ├── 9 rt_1_tf_trained_for_000001120
# │       ├── 9 octo-base
# │       └── 0 openvla-7b
# ├── recolor_tabletop_visual_matching_2
# │   ├── OpenTopDrawerCustomInScene-v0
# │   │   ├── 9 rt_1_tf_trained_for_000400120
# │   │   ├── 9 rt_1_tf_trained_for_000058240
# │   │   ├── 9 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 9 rt_1_tf_trained_for_000001120
# │   │   ├── 9 octo-base
# │   │   └── 0 openvla-7b
# │   ├── OpenMiddleDrawerCustomInScene-v0
# │   │   ├── 9 rt_1_tf_trained_for_000400120
# │   │   ├── 9 rt_1_tf_trained_for_000058240
# │   │   ├── 9 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 9 rt_1_tf_trained_for_000001120
# │   │   ├── 9 octo-base
# │   │   └── 0 openvla-7b
# │   ├── OpenBottomDrawerCustomInScene-v0
# │   │   ├── 9 rt_1_tf_trained_for_000400120
# │   │   ├── 9 rt_1_tf_trained_for_000058240
# │   │   ├── 9 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 9 rt_1_tf_trained_for_000001120
# │   │   ├── 9 octo-base
# │   │   └── 0 openvla-7b
# │   ├── CloseTopDrawerCustomInScene-v0
# │   │   ├── 9 rt_1_tf_trained_for_000400120
# │   │   ├── 9 rt_1_tf_trained_for_000058240
# │   │   ├── 9 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 9 rt_1_tf_trained_for_000001120
# │   │   ├── 9 octo-base
# │   │   └── 0 openvla-7b
# │   ├── CloseMiddleDrawerCustomInScene-v0
# │   │   ├── 9 rt_1_tf_trained_for_000400120
# │   │   ├── 9 rt_1_tf_trained_for_000058240
# │   │   ├── 9 rt_1_x_tf_trained_for_002272480_step
# │   │   ├── 9 rt_1_tf_trained_for_000001120
# │   │   ├── 9 octo-base
# │   │   └── 0 openvla-7b
# │   └── CloseBottomDrawerCustomInScene-v0
# │       ├── 9 rt_1_tf_trained_for_000400120
# │       ├── 9 rt_1_tf_trained_for_000058240
# │       ├── 9 rt_1_x_tf_trained_for_002272480_step
# │       ├── 9 rt_1_tf_trained_for_000001120
# │       ├── 9 octo-base
# │       └── 0 openvla-7b
# └── None
#     ├── OpenTopDrawerCustomInScene-v0
#     │   ├── 9 rt_1_tf_trained_for_000400120
#     │   ├── 9 rt_1_tf_trained_for_000058240
#     │   ├── 9 rt_1_x_tf_trained_for_002272480_step
#     │   ├── 9 rt_1_tf_trained_for_000001120
#     │   ├── 9 octo-base
#     │   └── 0 openvla-7b
#     ├── OpenMiddleDrawerCustomInScene-v0
#     │   ├── 9 rt_1_tf_trained_for_000400120
#     │   ├── 9 rt_1_tf_trained_for_000058240
#     │   ├── 9 rt_1_x_tf_trained_for_002272480_step
#     │   ├── 9 rt_1_tf_trained_for_000001120
#     │   ├── 9 octo-base
#     │   └── 0 openvla-7b
#     ├── OpenBottomDrawerCustomInScene-v0
#     │   ├── 9 rt_1_tf_trained_for_000400120
#     │   ├── 9 rt_1_tf_trained_for_000058240
#     │   ├── 9 rt_1_x_tf_trained_for_002272480_step
#     │   ├── 9 rt_1_tf_trained_for_000001120
#     │   ├── 9 octo-base
#     │   └── 0 openvla-7b
#     ├── CloseTopDrawerCustomInScene-v0
#     │   ├── 9 rt_1_tf_trained_for_000400120
#     │   ├── 9 rt_1_tf_trained_for_000058240
#     │   ├── 9 rt_1_x_tf_trained_for_002272480_step
#     │   ├── 9 rt_1_tf_trained_for_000001120
#     │   ├── 9 octo-base
#     │   └── 0 openvla-7b
#     ├── CloseMiddleDrawerCustomInScene-v0
#     │   ├── 9 rt_1_tf_trained_for_000400120
#     │   ├── 9 rt_1_tf_trained_for_000058240
#     │   ├── 9 rt_1_x_tf_trained_for_002272480_step
#     │   ├── 9 rt_1_tf_trained_for_000001120
#     │   ├── 9 octo-base
#     │   └── 0 openvla-7b
#     └── CloseBottomDrawerCustomInScene-v0
#         ├── 9 rt_1_tf_trained_for_000400120
#         ├── 9 rt_1_tf_trained_for_000058240
#         ├── 9 rt_1_x_tf_trained_for_002272480_step
#         ├── 9 rt_1_tf_trained_for_000001120
#         ├── 9 octo-base
#         └── 0 openvla-7b
# Eval Results
# ├── dummy_tabletop1
# │   ├── recolor_cabinet_visual_matching_1
# │   │   └── GraspSingleOpenedCokeCanInScene-v0
# │   │       ├── rt_1_tf_trained_for_000400120
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── rt_1_tf_trained_for_000058240
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── rt_1_x_tf_trained_for_002272480_step
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── rt_1_tf_trained_for_000001120
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── octo-base
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       └── openvla-7b
# │   │           ├── 0 lr_switch_True
# │   │           ├── 0 laid_vertically_True
# │   │           └── 0 upright_True
# │   ├── recolor_tabletop_visual_matching_1
# │   │   └── GraspSingleOpenedCokeCanInScene-v0
# │   │       ├── rt_1_tf_trained_for_000400120
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── rt_1_tf_trained_for_000058240
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── rt_1_x_tf_trained_for_002272480_step
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── rt_1_tf_trained_for_000001120
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── octo-base
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       └── openvla-7b
# │   │           ├── 25 lr_switch_True
# │   │           ├── 25 laid_vertically_True
# │   │           └── 25 upright_True
# │   ├── recolor_tabletop_visual_matching_2
# │   │   └── GraspSingleOpenedCokeCanInScene-v0
# │   │       ├── rt_1_tf_trained_for_000400120
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── rt_1_tf_trained_for_000058240
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── rt_1_x_tf_trained_for_002272480_step
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── rt_1_tf_trained_for_000001120
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       ├── octo-base
# │   │       │   ├── 25 lr_switch_True
# │   │       │   ├── 25 laid_vertically_True
# │   │       │   └── 25 upright_True
# │   │       └── openvla-7b
# │   │           ├── 23 lr_switch_True
# │   │           ├── 0 laid_vertically_True
# │   │           └── 23 upright_True
# │   └── None
# │       └── GraspSingleOpenedCokeCanInScene-v0
# │           ├── rt_1_tf_trained_for_000400120
# │           │   ├── 25 lr_switch_True
# │           │   ├── 25 laid_vertically_True
# │           │   └── 25 upright_True
# │           ├── rt_1_tf_trained_for_000058240
# │           │   ├── 25 lr_switch_True
# │           │   ├── 25 laid_vertically_True
# │           │   └── 25 upright_True
# │           ├── rt_1_x_tf_trained_for_002272480_step
# │           │   ├── 25 lr_switch_True
# │           │   ├── 25 laid_vertically_True
# │           │   └── 25 upright_True
# │           ├── rt_1_tf_trained_for_000001120
# │           │   ├── 25 lr_switch_True
# │           │   ├── 25 laid_vertically_True
# │           │   └── 25 upright_True
# │           ├── octo-base
# │           │   ├── 25 lr_switch_True
# │           │   ├── 25 laid_vertically_True
# │           │   └── 25 upright_True
# │           └── openvla-7b
# │               ├── 25 lr_switch_True
# │               ├── 25 laid_vertically_True
# │               └── 25 upright_True
# └── dummy_wood_tabletop
#     ├── recolor_cabinet_visual_matching_1
#     │   └── GraspSingleOpenedCokeCanInScene-v0
#     │       ├── rt_1_tf_trained_for_000400120
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── rt_1_tf_trained_for_000058240
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── rt_1_x_tf_trained_for_002272480_step
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── rt_1_tf_trained_for_000001120
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── octo-base
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       └── openvla-7b
#     │           ├── 25 lr_switch_True
#     │           ├── 25 laid_vertically_True
#     │           └── 25 upright_True
#     ├── recolor_tabletop_visual_matching_1
#     │   └── GraspSingleOpenedCokeCanInScene-v0
#     │       ├── rt_1_tf_trained_for_000400120
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── rt_1_tf_trained_for_000058240
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── rt_1_x_tf_trained_for_002272480_step
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── rt_1_tf_trained_for_000001120
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── octo-base
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       └── openvla-7b
#     │           ├── 25 lr_switch_True
#     │           ├── 25 laid_vertically_True
#     │           └── 25 upright_True
#     ├── recolor_tabletop_visual_matching_2
#     │   └── GraspSingleOpenedCokeCanInScene-v0
#     │       ├── rt_1_tf_trained_for_000400120
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── rt_1_tf_trained_for_000058240
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── rt_1_x_tf_trained_for_002272480_step
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── rt_1_tf_trained_for_000001120
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       ├── octo-base
#     │       │   ├── 25 lr_switch_True
#     │       │   ├── 25 laid_vertically_True
#     │       │   └── 25 upright_True
#     │       └── openvla-7b
#     │           ├── 25 lr_switch_True
#     │           ├── 25 laid_vertically_True
#     │           └── 25 upright_True
#     └── None
#         └── GraspSingleOpenedCokeCanInScene-v0
#             ├── rt_1_tf_trained_for_000400120
#             │   ├── 25 lr_switch_True
#             │   ├── 25 laid_vertically_True
#             │   └── 25 upright_True
#             ├── rt_1_tf_trained_for_000058240
#             │   ├── 25 lr_switch_True
#             │   ├── 25 laid_vertically_True
#             │   └── 25 upright_True
#             ├── rt_1_x_tf_trained_for_002272480_step
#             │   ├── 25 lr_switch_True
#             │   ├── 25 laid_vertically_True
#             │   └── 25 upright_True
#             ├── rt_1_tf_trained_for_000001120
#             │   ├── 25 lr_switch_True
#             │   ├── 25 laid_vertically_True
#             │   └── 25 upright_True
#             ├── octo-base
#             │   ├── 25 lr_switch_True
#             │   ├── 25 laid_vertically_True
#             │   └── 25 upright_True
#             └── openvla-7b
#                 ├── 25 lr_switch_True
#                 ├── 25 laid_vertically_True
#                 └── 25 upright_True
# Eval Results
# ├── recolor_cabinet_visual_matching_1
# │   └── MoveNearGoogleBakedTexInScene-v0
# │       ├── 60 rt_1_tf_trained_for_000400120
# │       ├── 60 rt_1_tf_trained_for_000058240
# │       ├── 60 rt_1_x_tf_trained_for_002272480_step
# │       ├── 60 rt_1_tf_trained_for_000001120
# │       ├── 60 octo-base
# │       └── 0 openvla-7b
# ├── recolor_tabletop_visual_matching_1
# │   └── MoveNearGoogleBakedTexInScene-v0
# │       ├── 60 rt_1_tf_trained_for_000400120
# │       ├── 60 rt_1_tf_trained_for_000058240
# │       ├── 60 rt_1_x_tf_trained_for_002272480_step
# │       ├── 60 rt_1_tf_trained_for_000001120
# │       ├── 60 octo-base
# │       └── 0 openvla-7b
# ├── recolor_tabletop_visual_matching_2
# │   └── MoveNearGoogleBakedTexInScene-v0
# │       ├── 60 rt_1_tf_trained_for_000400120
# │       ├── 60 rt_1_tf_trained_for_000058240
# │       ├── 60 rt_1_x_tf_trained_for_002272480_step
# │       ├── 60 rt_1_tf_trained_for_000001120
# │       ├── 60 octo-base
# │       └── 0 openvla-7b
# └── None
#     └── MoveNearGoogleBakedTexInScene-v0
#         ├── 60 rt_1_tf_trained_for_000400120
#         ├── 60 rt_1_tf_trained_for_000058240
#         ├── 60 rt_1_x_tf_trained_for_002272480_step
#         ├── 60 rt_1_tf_trained_for_000001120
#         ├── 60 octo-base
#         └── 0 openvla-7b
# Eval Results
# ├── recolor_cabinet_visual_matching_1
# │   └── PlaceIntoClosedTopDrawerCustomInScene-v0
# │       ├── 27 rt_1_tf_trained_for_000400120
# │       ├── 27 rt_1_tf_trained_for_000058240
# │       ├── 27 rt_1_x_tf_trained_for_002272480_step
# │       ├── 27 rt_1_tf_trained_for_000001120
# │       ├── 27 octo-base
# │       └── 0 openvla-7b
# ├── recolor_tabletop_visual_matching_1
# │   └── PlaceIntoClosedTopDrawerCustomInScene-v0
# │       ├── 27 rt_1_tf_trained_for_000400120
# │       ├── 27 rt_1_tf_trained_for_000058240
# │       ├── 27 rt_1_x_tf_trained_for_002272480_step
# │       ├── 27 rt_1_tf_trained_for_000001120
# │       ├── 27 octo-base
# │       └── 0 openvla-7b
# ├── recolor_tabletop_visual_matching_2
# │   └── PlaceIntoClosedTopDrawerCustomInScene-v0
# │       ├── 27 rt_1_tf_trained_for_000400120
# │       ├── 27 rt_1_tf_trained_for_000058240
# │       ├── 27 rt_1_x_tf_trained_for_002272480_step
# │       ├── 27 rt_1_tf_trained_for_000001120
# │       ├── 27 octo-base
# │       └── 0 openvla-7b
# └── None
#     └── PlaceIntoClosedTopDrawerCustomInScene-v0
#         ├── 27 rt_1_tf_trained_for_000400120
#         ├── 27 rt_1_tf_trained_for_000058240
#         ├── 27 rt_1_x_tf_trained_for_002272480_step
#         ├── 27 rt_1_tf_trained_for_000001120
#         ├── 27 octo-base
#         └── 0 openvla-7b

# %% [markdown]
# ### Evaluate the Results

# %%
from anytree import Node, RenderTree
import re
from collections import Counter

def filter_files(filenames, patterns):
    # Return the count and list of filenames that match all given patterns.
    matches = [f for f in filenames if all(re.search(p, f) for p in patterns)]
    return len(matches), matches

def create_parent_node(name, aggregated, children):
    """
    Given a name, a dictionary of aggregated counts, and a list of child nodes,
    compute the success rate and create a summary Node with attributes success,
    failure, and success_rate. If the sum of counts is zero, return None.
    """
    success = aggregated.get("success", 0)
    failure = aggregated.get("failure", 0)
    total = success + failure
    if total == 0:
        return None
    success_rate = success / total
    # Create the parent node with attributes; the label is just the name.
    parent = Node(name, success=success, failure=failure, success_rate=success_rate)
    for child in children:
        child.parent = parent
    return parent

# Recursively builds a node returns a tuple (aggregated_counts, node).
def build_tree(name, levels, extra_pattern):
    # Base case: last level with outcomes (e.g., "success" and "failure")
    if len(levels) == 1:
        aggregated = {}
        children = []
        for outcome in levels[0]:
            pat, outcome_label = outcome if isinstance(outcome, tuple) else (outcome, outcome)
            count, _ = filter_files(filenames, extra_pattern + [pat])
            aggregated[outcome_label] = count
            if count > 0:
                children.append(Node(f"{count} {outcome_label}"))
        parent_node = create_parent_node(name, aggregated, children)
        return aggregated, parent_node
    else:
        aggregated_total = Counter()
        children = []
        for item in levels[0]:
            pat, node_name = item if isinstance(item, tuple) else (item, item)
            child_aggregated, child_node = build_tree(node_name, levels[1:], extra_pattern + [pat])
            aggregated_total.update(child_aggregated)
            if child_node is not None:
                children.append(child_node)
        parent_node = create_parent_node(name, dict(aggregated_total), children)
        return dict(aggregated_total), parent_node

#Recursively retrives the node specified by the pattern_list
def get_node(root, pattern_list):
    if not pattern_list:
        return root
    for child in root.children:
        if child.name == pattern_list[0]:
            result = get_node(child, pattern_list[1:])
            if result is not None:
                return result
    # allow skipping if only one child exists 
    if len(root.children) == 1:
        result = get_node(root.children[0], pattern_list)
        if result is not None:
            return result
    return None

# Print the entire tree
def print_tree(tree):
    for pre, _, node in RenderTree(tree):
        stats = f"-> success: {node.success}, failure: {node.failure}, success_rate: {node.success_rate:.3f}" if node.children else ""
        print(f"{pre}{node.name} {stats}")

# %% [markdown]
# ### Build Tree for Drawer Tasks

# %%
outcome = ["success", "failure"]
higher_tasks = [(r"Open(?:Bottom|Top|Middle)Drawer", "google_robot_open_drawer"),
                (r"Close(?:Bottom|Top|Middle)Drawer", "google_robot_close_drawer")]
# Insert intermediate aggregate levels (can be arbitrary)
average_level = [(r"(?:Open|Close)(?:Bottom|Top|Middle)Drawer","google_robot_drawer_avg")]
#average_level = [(r"","google_robot_drawer_avg")]
levels = [policies, average_level, higher_tasks, drawer_tasks, urdf_versions, outcome]
_ , drawer_tree = build_tree("Eval Results for Drawer Tasks", levels, [])
print_tree(drawer_tree)
# Out:
# Eval Results for Drawer Tasks -> success: 476, failure: 604, success_rate: 0.441
# ├── rt_1_tf_trained_for_000400120 -> success: 154, failure: 62, success_rate: 0.713
# │   └── google_robot_drawer_avg -> success: 154, failure: 62, success_rate: 0.713
# │       ├── google_robot_open_drawer -> success: 63, failure: 45, success_rate: 0.583
# │       │   ├── OpenTopDrawerCustomInScene-v0 -> success: 23, failure: 13, success_rate: 0.639
# │       │   │   ├── recolor_cabinet_visual_matching_1 -> success: 6, failure: 3, success_rate: 0.667
# │       │   │   │   ├── 6 success
# │       │   │   │   └── 3 failure
# │       │   │   ├── recolor_tabletop_visual_matching_1 -> success: 6, failure: 3, success_rate: 0.667
# │       │   │   │   ├── 6 success
# │       │   │   │   └── 3 failure
# │       │   │   ├── recolor_tabletop_visual_matching_2 -> success: 5, failure: 4, success_rate: 0.556
# │       │   │   │   ├── 5 success
# │       │   │   │   └── 4 failure
# │       │   │   └── None -> success: 6, failure: 3, success_rate: 0.667
# │       │   │       ├── 6 success
# │       │   │       └── 3 failure
# │       │   ├── OpenMiddleDrawerCustomInScene-v0 -> success: 27, failure: 9, success_rate: 0.750
# │       │   │   ├── recolor_cabinet_visual_matching_1 -> success: 7, failure: 2, success_rate: 0.778
# │       │   │   │   ├── 7 success
# │       │   │   │   └── 2 failure
# │       │   │   ├── recolor_tabletop_visual_matching_1 -> success: 8, failure: 1, success_rate: 0.889
# │       │   │   │   ├── 8 success
# │       │   │   │   └── 1 failure
# │       │   │   ├── recolor_tabletop_visual_matching_2 -> success: 8, failure: 1, success_rate: 0.889
# │       │   │   │   ├── 8 success
# │       │   │   │   └── 1 failure
# │       │   │   └── None -> success: 4, failure: 5, success_rate: 0.444
# │       │   │       ├── 4 success
# │       │   │       └── 5 failure
# │       │   └── OpenBottomDrawerCustomInScene-v0 -> success: 13, failure: 23, success_rate: 0.361
# │       │       ├── recolor_cabinet_visual_matching_1 -> success: 6, failure: 3, success_rate: 0.667
# │       │       │   ├── 6 success
# │       │       │   └── 3 failure
# │       │       ├── recolor_tabletop_visual_matching_1 -> success: 4, failure: 5, success_rate: 0.444
# │       │       │   ├── 4 success
# │       │       │   └── 5 failure
# │       │       ├── recolor_tabletop_visual_matching_2 -> success: 3, failure: 6, success_rate: 0.333
# │       │       │   ├── 3 success
# │       │       │   └── 6 failure
# │       │       └── None -> success: 0, failure: 9, success_rate: 0.000
# │       │           └── 9 failure
# │       └── google_robot_close_drawer -> success: 91, failure: 17, success_rate: 0.843
# │           ├── CloseTopDrawerCustomInScene-v0 -> success: 36, failure: 0, success_rate: 1.000
# │           │   ├── recolor_cabinet_visual_matching_1 -> success: 9, failure: 0, success_rate: 1.000
# │           │   │   └── 9 success
# │           │   ├── recolor_tabletop_visual_matching_1 -> success: 9, failure: 0, success_rate: 1.000
# │           │   │   └── 9 success
# │           │   ├── recolor_tabletop_visual_matching_2 -> success: 9, failure: 0, success_rate: 1.000
# │           │   │   └── 9 success
# │           │   └── None -> success: 9, failure: 0, success_rate: 1.000
# │           │       └── 9 success
# │           ├── CloseMiddleDrawerCustomInScene-v0 -> success: 33, failure: 3, success_rate: 0.917
# │           │   ├── recolor_cabinet_visual_matching_1 -> success: 8, failure: 1, success_rate: 0.889
# │           │   │   ├── 8 success
# │           │   │   └── 1 failure
# │           │   ├── recolor_tabletop_visual_matching_1 -> success: 8, failure: 1, success_rate: 0.889
# │           │   │   ├── 8 success
# │           │   │   └── 1 failure
# │           │   ├── recolor_tabletop_visual_matching_2 -> success: 9, failure: 0, success_rate: 1.000
# │           │   │   └── 9 success
# │           │   └── None -> success: 8, failure: 1, success_rate: 0.889
# │           │       ├── 8 success
# │           │       └── 1 failure
# │           └── CloseBottomDrawerCustomInScene-v0 -> success: 22, failure: 14, success_rate: 0.611
# │               ├── recolor_cabinet_visual_matching_1 -> success: 5, failure: 4, success_rate: 0.556
# │               │   ├── 5 success
# │               │   └── 4 failure
# │               ├── recolor_tabletop_visual_matching_1 -> success: 8, failure: 1, success_rate: 0.889
# │               │   ├── 8 success
# │               │   └── 1 failure
# │               ├── recolor_tabletop_visual_matching_2 -> success: 7, failure: 2, success_rate: 0.778
# │               │   ├── 7 success
# │               │   └── 2 failure
# │               └── None -> success: 2, failure: 7, success_rate: 0.222
# │                   ├── 2 success
# │                   └── 7 failure
# ├── rt_1_tf_trained_for_000058240 -> success: 121, failure: 95, success_rate: 0.560
# │   └── google_robot_drawer_avg -> success: 121, failure: 95, success_rate: 0.560
# │       ├── google_robot_open_drawer -> success: 47, failure: 61, success_rate: 0.435
# │       │   ├── OpenTopDrawerCustomInScene-v0 -> success: 18, failure: 18, success_rate: 0.500
# │       │   │   ├── recolor_cabinet_visual_matching_1 -> success: 3, failure: 6, success_rate: 0.333
# │       │   │   │   ├── 3 success
# │       │   │   │   └── 6 failure
# │       │   │   ├── recolor_tabletop_visual_matching_1 -> success: 5, failure: 4, success_rate: 0.556
# │       │   │   │   ├── 5 success
# │       │   │   │   └── 4 failure
# │       │   │   ├── recolor_tabletop_visual_matching_2 -> success: 5, failure: 4, success_rate: 0.556
# │       │   │   │   ├── 5 success
# │       │   │   │   └── 4 failure
# │       │   │   └── None -> success: 5, failure: 4, success_rate: 0.556
# │       │   │       ├── 5 success
# │       │   │       └── 4 failure
# │       │   ├── OpenMiddleDrawerCustomInScene-v0 -> success: 18, failure: 18, success_rate: 0.500
# │       │   │   ├── recolor_cabinet_visual_matching_1 -> success: 4, failure: 5, success_rate: 0.444
# │       │   │   │   ├── 4 success
# │       │   │   │   └── 5 failure
# │       │   │   ├── recolor_tabletop_visual_matching_1 -> success: 3, failure: 6, success_rate: 0.333
# │       │   │   │   ├── 3 success
# │       │   │   │   └── 6 failure
# │       │   │   ├── recolor_tabletop_visual_matching_2 -> success: 6, failure: 3, success_rate: 0.667
# │       │   │   │   ├── 6 success
# │       │   │   │   └── 3 failure
# │       │   │   └── None -> success: 5, failure: 4, success_rate: 0.556
# │       │   │       ├── 5 success
# │       │   │       └── 4 failure
# │       │   └── OpenBottomDrawerCustomInScene-v0 -> success: 11, failure: 25, success_rate: 0.306
# │       │       ├── recolor_cabinet_visual_matching_1 -> success: 4, failure: 5, success_rate: 0.444
# │       │       │   ├── 4 success
# │       │       │   └── 5 failure
# │       │       ├── recolor_tabletop_visual_matching_1 -> success: 4, failure: 5, success_rate: 0.444
# │       │       │   ├── 4 success
# │       │       │   └── 5 failure
# │       │       ├── recolor_tabletop_visual_matching_2 -> success: 2, failure: 7, success_rate: 0.222
# │       │       │   ├── 2 success
# │       │       │   └── 7 failure
# │       │       └── None -> success: 1, failure: 8, success_rate: 0.111
# │       │           ├── 1 success
# │       │           └── 8 failure
# │       └── google_robot_close_drawer -> success: 74, failure: 34, success_rate: 0.685
# │           ├── CloseTopDrawerCustomInScene-v0 -> success: 26, failure: 10, success_rate: 0.722
# │           │   ├── recolor_cabinet_visual_matching_1 -> success: 7, failure: 2, success_rate: 0.778
# │           │   │   ├── 7 success
# │           │   │   └── 2 failure
# │           │   ├── recolor_tabletop_visual_matching_1 -> success: 7, failure: 2, success_rate: 0.778
# │           │   │   ├── 7 success
# │           │   │   └── 2 failure
# │           │   ├── recolor_tabletop_visual_matching_2 -> success: 7, failure: 2, success_rate: 0.778
# │           │   │   ├── 7 success
# │           │   │   └── 2 failure
# │           │   └── None -> success: 5, failure: 4, success_rate: 0.556
# │           │       ├── 5 success
# │           │       └── 4 failure
# │           ├── CloseMiddleDrawerCustomInScene-v0 -> success: 30, failure: 6, success_rate: 0.833
# │           │   ├── recolor_cabinet_visual_matching_1 -> success: 7, failure: 2, success_rate: 0.778
# │           │   │   ├── 7 success
# │           │   │   └── 2 failure
# │           │   ├── recolor_tabletop_visual_matching_1 -> success: 7, failure: 2, success_rate: 0.778
# │           │   │   ├── 7 success
# │           │   │   └── 2 failure
# │           │   ├── recolor_tabletop_visual_matching_2 -> success: 8, failure: 1, success_rate: 0.889
# │           │   │   ├── 8 success
# │           │   │   └── 1 failure
# │           │   └── None -> success: 8, failure: 1, success_rate: 0.889
# │           │       ├── 8 success
# │           │       └── 1 failure
# │           └── CloseBottomDrawerCustomInScene-v0 -> success: 18, failure: 18, success_rate: 0.500
# │               ├── recolor_cabinet_visual_matching_1 -> success: 5, failure: 4, success_rate: 0.556
# │               │   ├── 5 success
# │               │   └── 4 failure
# │               ├── recolor_tabletop_visual_matching_1 -> success: 5, failure: 4, success_rate: 0.556
# │               │   ├── 5 success
# │               │   └── 4 failure
# │               ├── recolor_tabletop_visual_matching_2 -> success: 4, failure: 5, success_rate: 0.444
# │               │   ├── 4 success
# │               │   └── 5 failure
# │               └── None -> success: 4, failure: 5, success_rate: 0.444
# │                   ├── 4 success
# │                   └── 5 failure
# ├── rt_1_x_tf_trained_for_002272480_step -> success: 128, failure: 88, success_rate: 0.593
# │   └── google_robot_drawer_avg -> success: 128, failure: 88, success_rate: 0.593
# │       ├── google_robot_open_drawer -> success: 28, failure: 80, success_rate: 0.259
# │       │   ├── OpenTopDrawerCustomInScene-v0 -> success: 7, failure: 29, success_rate: 0.194
# │       │   │   ├── recolor_cabinet_visual_matching_1 -> success: 2, failure: 7, success_rate: 0.222
# │       │   │   │   ├── 2 success
# │       │   │   │   └── 7 failure
# │       │   │   ├── recolor_tabletop_visual_matching_1 -> success: 2, failure: 7, success_rate: 0.222
# │       │   │   │   ├── 2 success
# │       │   │   │   └── 7 failure
# │       │   │   ├── recolor_tabletop_visual_matching_2 -> success: 1, failure: 8, success_rate: 0.111
# │       │   │   │   ├── 1 success
# │       │   │   │   └── 8 failure
# │       │   │   └── None -> success: 2, failure: 7, success_rate: 0.222
# │       │   │       ├── 2 success
# │       │   │       └── 7 failure
# │       │   ├── OpenMiddleDrawerCustomInScene-v0 -> success: 12, failure: 24, success_rate: 0.333
# │       │   │   ├── recolor_cabinet_visual_matching_1 -> success: 4, failure: 5, success_rate: 0.444
# │       │   │   │   ├── 4 success
# │       │   │   │   └── 5 failure
# │       │   │   ├── recolor_tabletop_visual_matching_1 -> success: 3, failure: 6, success_rate: 0.333
# │       │   │   │   ├── 3 success
# │       │   │   │   └── 6 failure
# │       │   │   ├── recolor_tabletop_visual_matching_2 -> success: 3, failure: 6, success_rate: 0.333
# │       │   │   │   ├── 3 success
# │       │   │   │   └── 6 failure
# │       │   │   └── None -> success: 2, failure: 7, success_rate: 0.222
# │       │   │       ├── 2 success
# │       │   │       └── 7 failure
# │       │   └── OpenBottomDrawerCustomInScene-v0 -> success: 9, failure: 27, success_rate: 0.250
# │       │       ├── recolor_cabinet_visual_matching_1 -> success: 5, failure: 4, success_rate: 0.556
# │       │       │   ├── 5 success
# │       │       │   └── 4 failure
# │       │       ├── recolor_tabletop_visual_matching_1 -> success: 2, failure: 7, success_rate: 0.222
# │       │       │   ├── 2 success
# │       │       │   └── 7 failure
# │       │       ├── recolor_tabletop_visual_matching_2 -> success: 2, failure: 7, success_rate: 0.222
# │       │       │   ├── 2 success
# │       │       │   └── 7 failure
# │       │       └── None -> success: 0, failure: 9, success_rate: 0.000
# │       │           └── 9 failure
# │       └── google_robot_close_drawer -> success: 100, failure: 8, success_rate: 0.926
# │           ├── CloseTopDrawerCustomInScene-v0 -> success: 34, failure: 2, success_rate: 0.944
# │           │   ├── recolor_cabinet_visual_matching_1 -> success: 8, failure: 1, success_rate: 0.889
# │           │   │   ├── 8 success
# │           │   │   └── 1 failure
# │           │   ├── recolor_tabletop_visual_matching_1 -> success: 9, failure: 0, success_rate: 1.000
# │           │   │   └── 9 success
# │           │   ├── recolor_tabletop_visual_matching_2 -> success: 8, failure: 1, success_rate: 0.889
# │           │   │   ├── 8 success
# │           │   │   └── 1 failure
# │           │   └── None -> success: 9, failure: 0, success_rate: 1.000
# │           │       └── 9 success
# │           ├── CloseMiddleDrawerCustomInScene-v0 -> success: 36, failure: 0, success_rate: 1.000
# │           │   ├── recolor_cabinet_visual_matching_1 -> success: 9, failure: 0, success_rate: 1.000
# │           │   │   └── 9 success
# │           │   ├── recolor_tabletop_visual_matching_1 -> success: 9, failure: 0, success_rate: 1.000
# │           │   │   └── 9 success
# │           │   ├── recolor_tabletop_visual_matching_2 -> success: 9, failure: 0, success_rate: 1.000
# │           │   │   └── 9 success
# │           │   └── None -> success: 9, failure: 0, success_rate: 1.000
# │           │       └── 9 success
# │           └── CloseBottomDrawerCustomInScene-v0 -> success: 30, failure: 6, success_rate: 0.833
# │               ├── recolor_cabinet_visual_matching_1 -> success: 8, failure: 1, success_rate: 0.889
# │               │   ├── 8 success
# │               │   └── 1 failure
# │               ├── recolor_tabletop_visual_matching_1 -> success: 8, failure: 1, success_rate: 0.889
# │               │   ├── 8 success
# │               │   └── 1 failure
# │               ├── recolor_tabletop_visual_matching_2 -> success: 7, failure: 2, success_rate: 0.778
# │               │   ├── 7 success
# │               │   └── 2 failure
# │               └── None -> success: 7, failure: 2, success_rate: 0.778
# │                   ├── 7 success
# │                   └── 2 failure
# ├── rt_1_tf_trained_for_000001120 -> success: 26, failure: 190, success_rate: 0.120
# │   └── google_robot_drawer_avg -> success: 26, failure: 190, success_rate: 0.120
# │       ├── google_robot_open_drawer -> success: 0, failure: 108, success_rate: 0.000
# │       │   ├── OpenTopDrawerCustomInScene-v0 -> success: 0, failure: 36, success_rate: 0.000
# │       │   │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 9, success_rate: 0.000
# │       │   │   │   └── 9 failure
# │       │   │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 9, success_rate: 0.000
# │       │   │   │   └── 9 failure
# │       │   │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 9, success_rate: 0.000
# │       │   │   │   └── 9 failure
# │       │   │   └── None -> success: 0, failure: 9, success_rate: 0.000
# │       │   │       └── 9 failure
# │       │   ├── OpenMiddleDrawerCustomInScene-v0 -> success: 0, failure: 36, success_rate: 0.000
# │       │   │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 9, success_rate: 0.000
# │       │   │   │   └── 9 failure
# │       │   │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 9, success_rate: 0.000
# │       │   │   │   └── 9 failure
# │       │   │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 9, success_rate: 0.000
# │       │   │   │   └── 9 failure
# │       │   │   └── None -> success: 0, failure: 9, success_rate: 0.000
# │       │   │       └── 9 failure
# │       │   └── OpenBottomDrawerCustomInScene-v0 -> success: 0, failure: 36, success_rate: 0.000
# │       │       ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 9, success_rate: 0.000
# │       │       │   └── 9 failure
# │       │       ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 9, success_rate: 0.000
# │       │       │   └── 9 failure
# │       │       ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 9, success_rate: 0.000
# │       │       │   └── 9 failure
# │       │       └── None -> success: 0, failure: 9, success_rate: 0.000
# │       │           └── 9 failure
# │       └── google_robot_close_drawer -> success: 26, failure: 82, success_rate: 0.241
# │           ├── CloseTopDrawerCustomInScene-v0 -> success: 11, failure: 25, success_rate: 0.306
# │           │   ├── recolor_cabinet_visual_matching_1 -> success: 2, failure: 7, success_rate: 0.222
# │           │   │   ├── 2 success
# │           │   │   └── 7 failure
# │           │   ├── recolor_tabletop_visual_matching_1 -> success: 4, failure: 5, success_rate: 0.444
# │           │   │   ├── 4 success
# │           │   │   └── 5 failure
# │           │   ├── recolor_tabletop_visual_matching_2 -> success: 3, failure: 6, success_rate: 0.333
# │           │   │   ├── 3 success
# │           │   │   └── 6 failure
# │           │   └── None -> success: 2, failure: 7, success_rate: 0.222
# │           │       ├── 2 success
# │           │       └── 7 failure
# │           ├── CloseMiddleDrawerCustomInScene-v0 -> success: 13, failure: 23, success_rate: 0.361
# │           │   ├── recolor_cabinet_visual_matching_1 -> success: 4, failure: 5, success_rate: 0.444
# │           │   │   ├── 4 success
# │           │   │   └── 5 failure
# │           │   ├── recolor_tabletop_visual_matching_1 -> success: 2, failure: 7, success_rate: 0.222
# │           │   │   ├── 2 success
# │           │   │   └── 7 failure
# │           │   ├── recolor_tabletop_visual_matching_2 -> success: 5, failure: 4, success_rate: 0.556
# │           │   │   ├── 5 success
# │           │   │   └── 4 failure
# │           │   └── None -> success: 2, failure: 7, success_rate: 0.222
# │           │       ├── 2 success
# │           │       └── 7 failure
# │           └── CloseBottomDrawerCustomInScene-v0 -> success: 2, failure: 34, success_rate: 0.056
# │               ├── recolor_cabinet_visual_matching_1 -> success: 1, failure: 8, success_rate: 0.111
# │               │   ├── 1 success
# │               │   └── 8 failure
# │               ├── recolor_tabletop_visual_matching_1 -> success: 1, failure: 8, success_rate: 0.111
# │               │   ├── 1 success
# │               │   └── 8 failure
# │               ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 9, success_rate: 0.000
# │               │   └── 9 failure
# │               └── None -> success: 0, failure: 9, success_rate: 0.000
# │                   └── 9 failure
# └── octo-base -> success: 47, failure: 169, success_rate: 0.218
#     └── google_robot_drawer_avg -> success: 47, failure: 169, success_rate: 0.218
#         ├── google_robot_open_drawer -> success: 1, failure: 107, success_rate: 0.009
#         │   ├── OpenTopDrawerCustomInScene-v0 -> success: 0, failure: 36, success_rate: 0.000
#         │   │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 9, success_rate: 0.000
#         │   │   │   └── 9 failure
#         │   │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 9, success_rate: 0.000
#         │   │   │   └── 9 failure
#         │   │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 9, success_rate: 0.000
#         │   │   │   └── 9 failure
#         │   │   └── None -> success: 0, failure: 9, success_rate: 0.000
#         │   │       └── 9 failure
#         │   ├── OpenMiddleDrawerCustomInScene-v0 -> success: 1, failure: 35, success_rate: 0.028
#         │   │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 9, success_rate: 0.000
#         │   │   │   └── 9 failure
#         │   │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 9, success_rate: 0.000
#         │   │   │   └── 9 failure
#         │   │   ├── recolor_tabletop_visual_matching_2 -> success: 1, failure: 8, success_rate: 0.111
#         │   │   │   ├── 1 success
#         │   │   │   └── 8 failure
#         │   │   └── None -> success: 0, failure: 9, success_rate: 0.000
#         │   │       └── 9 failure
#         │   └── OpenBottomDrawerCustomInScene-v0 -> success: 0, failure: 36, success_rate: 0.000
#         │       ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 9, success_rate: 0.000
#         │       │   └── 9 failure
#         │       ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 9, success_rate: 0.000
#         │       │   └── 9 failure
#         │       ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 9, success_rate: 0.000
#         │       │   └── 9 failure
#         │       └── None -> success: 0, failure: 9, success_rate: 0.000
#         │           └── 9 failure
#         └── google_robot_close_drawer -> success: 46, failure: 62, success_rate: 0.426
#             ├── CloseTopDrawerCustomInScene-v0 -> success: 23, failure: 13, success_rate: 0.639
#             │   ├── recolor_cabinet_visual_matching_1 -> success: 7, failure: 2, success_rate: 0.778
#             │   │   ├── 7 success
#             │   │   └── 2 failure
#             │   ├── recolor_tabletop_visual_matching_1 -> success: 7, failure: 2, success_rate: 0.778
#             │   │   ├── 7 success
#             │   │   └── 2 failure
#             │   ├── recolor_tabletop_visual_matching_2 -> success: 6, failure: 3, success_rate: 0.667
#             │   │   ├── 6 success
#             │   │   └── 3 failure
#             │   └── None -> success: 3, failure: 6, success_rate: 0.333
#             │       ├── 3 success
#             │       └── 6 failure
#             ├── CloseMiddleDrawerCustomInScene-v0 -> success: 14, failure: 22, success_rate: 0.389
#             │   ├── recolor_cabinet_visual_matching_1 -> success: 6, failure: 3, success_rate: 0.667
#             │   │   ├── 6 success
#             │   │   └── 3 failure
#             │   ├── recolor_tabletop_visual_matching_1 -> success: 5, failure: 4, success_rate: 0.556
#             │   │   ├── 5 success
#             │   │   └── 4 failure
#             │   ├── recolor_tabletop_visual_matching_2 -> success: 1, failure: 8, success_rate: 0.111
#             │   │   ├── 1 success
#             │   │   └── 8 failure
#             │   └── None -> success: 2, failure: 7, success_rate: 0.222
#             │       ├── 2 success
#             │       └── 7 failure
#             └── CloseBottomDrawerCustomInScene-v0 -> success: 9, failure: 27, success_rate: 0.250
#                 ├── recolor_cabinet_visual_matching_1 -> success: 2, failure: 7, success_rate: 0.222
#                 │   ├── 2 success
#                 │   └── 7 failure
#                 ├── recolor_tabletop_visual_matching_1 -> success: 3, failure: 6, success_rate: 0.333
#                 │   ├── 3 success
#                 │   └── 6 failure
#                 ├── recolor_tabletop_visual_matching_2 -> success: 3, failure: 6, success_rate: 0.333
#                 │   ├── 3 success
#                 │   └── 6 failure
#                 └── None -> success: 1, failure: 8, success_rate: 0.111
#                     ├── 1 success
#                     └── 8 failure

# %% [markdown]
# ### Build Tree for Pick Coke Can

# %%
orientation_tasks = [("lr_switch_True", "google_robot_pick_coke_can_horizontally_laying"), 
                     ("laid_vertically_True", "google_robot_pick_coke_can_vertically_laying"), 
                     ("upright_True", "google_robot_pick_coke_can_standing")]

#Note tuple for renaming purposes
pick_task= [("GraspSingleOpenedCokeCanInScene-v0", "google_robot_pick_coke_can")]
levels = [["google_pick_coke_can_1_v4"], policies, pick_task, orientation_tasks, urdf_versions, outcome]
_ , pick_coke_can_tree = build_tree("Eval Results For Pick Coke Can", levels, [])
print_tree(pick_coke_can_tree)
# Out:
# Eval Results For Pick Coke Can -> success: 709, failure: 791, success_rate: 0.473
# └── google_pick_coke_can_1_v4 -> success: 709, failure: 791, success_rate: 0.473
#     ├── rt_1_tf_trained_for_000400120 -> success: 259, failure: 41, success_rate: 0.863
#     │   └── google_robot_pick_coke_can -> success: 259, failure: 41, success_rate: 0.863
#     │       ├── google_robot_pick_coke_can_horizontally_laying -> success: 97, failure: 3, success_rate: 0.970
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 24, failure: 1, success_rate: 0.960
#     │       │   │   ├── 24 success
#     │       │   │   └── 1 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 24, failure: 1, success_rate: 0.960
#     │       │   │   ├── 24 success
#     │       │   │   └── 1 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 25, failure: 0, success_rate: 1.000
#     │       │   │   └── 25 success
#     │       │   └── None -> success: 24, failure: 1, success_rate: 0.960
#     │       │       ├── 24 success
#     │       │       └── 1 failure
#     │       ├── google_robot_pick_coke_can_vertically_laying -> success: 87, failure: 13, success_rate: 0.870
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 24, failure: 1, success_rate: 0.960
#     │       │   │   ├── 24 success
#     │       │   │   └── 1 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 19, failure: 6, success_rate: 0.760
#     │       │   │   ├── 19 success
#     │       │   │   └── 6 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 22, failure: 3, success_rate: 0.880
#     │       │   │   ├── 22 success
#     │       │   │   └── 3 failure
#     │       │   └── None -> success: 22, failure: 3, success_rate: 0.880
#     │       │       ├── 22 success
#     │       │       └── 3 failure
#     │       └── google_robot_pick_coke_can_standing -> success: 75, failure: 25, success_rate: 0.750
#     │           ├── recolor_cabinet_visual_matching_1 -> success: 15, failure: 10, success_rate: 0.600
#     │           │   ├── 15 success
#     │           │   └── 10 failure
#     │           ├── recolor_tabletop_visual_matching_1 -> success: 19, failure: 6, success_rate: 0.760
#     │           │   ├── 19 success
#     │           │   └── 6 failure
#     │           ├── recolor_tabletop_visual_matching_2 -> success: 20, failure: 5, success_rate: 0.800
#     │           │   ├── 20 success
#     │           │   └── 5 failure
#     │           └── None -> success: 21, failure: 4, success_rate: 0.840
#     │               ├── 21 success
#     │               └── 4 failure
#     ├── rt_1_tf_trained_for_000058240 -> success: 218, failure: 82, success_rate: 0.727
#     │   └── google_robot_pick_coke_can -> success: 218, failure: 82, success_rate: 0.727
#     │       ├── google_robot_pick_coke_can_horizontally_laying -> success: 90, failure: 10, success_rate: 0.900
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 22, failure: 3, success_rate: 0.880
#     │       │   │   ├── 22 success
#     │       │   │   └── 3 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 23, failure: 2, success_rate: 0.920
#     │       │   │   ├── 23 success
#     │       │   │   └── 2 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 24, failure: 1, success_rate: 0.960
#     │       │   │   ├── 24 success
#     │       │   │   └── 1 failure
#     │       │   └── None -> success: 21, failure: 4, success_rate: 0.840
#     │       │       ├── 21 success
#     │       │       └── 4 failure
#     │       ├── google_robot_pick_coke_can_vertically_laying -> success: 80, failure: 20, success_rate: 0.800
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 20, failure: 5, success_rate: 0.800
#     │       │   │   ├── 20 success
#     │       │   │   └── 5 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 23, failure: 2, success_rate: 0.920
#     │       │   │   ├── 23 success
#     │       │   │   └── 2 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 20, failure: 5, success_rate: 0.800
#     │       │   │   ├── 20 success
#     │       │   │   └── 5 failure
#     │       │   └── None -> success: 17, failure: 8, success_rate: 0.680
#     │       │       ├── 17 success
#     │       │       └── 8 failure
#     │       └── google_robot_pick_coke_can_standing -> success: 48, failure: 52, success_rate: 0.480
#     │           ├── recolor_cabinet_visual_matching_1 -> success: 13, failure: 12, success_rate: 0.520
#     │           │   ├── 13 success
#     │           │   └── 12 failure
#     │           ├── recolor_tabletop_visual_matching_1 -> success: 9, failure: 16, success_rate: 0.360
#     │           │   ├── 9 success
#     │           │   └── 16 failure
#     │           ├── recolor_tabletop_visual_matching_2 -> success: 13, failure: 12, success_rate: 0.520
#     │           │   ├── 13 success
#     │           │   └── 12 failure
#     │           └── None -> success: 13, failure: 12, success_rate: 0.520
#     │               ├── 13 success
#     │               └── 12 failure
#     ├── rt_1_x_tf_trained_for_002272480_step -> success: 170, failure: 130, success_rate: 0.567
#     │   └── google_robot_pick_coke_can -> success: 170, failure: 130, success_rate: 0.567
#     │       ├── google_robot_pick_coke_can_horizontally_laying -> success: 82, failure: 18, success_rate: 0.820
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 21, failure: 4, success_rate: 0.840
#     │       │   │   ├── 21 success
#     │       │   │   └── 4 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 23, failure: 2, success_rate: 0.920
#     │       │   │   ├── 23 success
#     │       │   │   └── 2 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 17, failure: 8, success_rate: 0.680
#     │       │   │   ├── 17 success
#     │       │   │   └── 8 failure
#     │       │   └── None -> success: 21, failure: 4, success_rate: 0.840
#     │       │       ├── 21 success
#     │       │       └── 4 failure
#     │       ├── google_robot_pick_coke_can_vertically_laying -> success: 31, failure: 69, success_rate: 0.310
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 6, failure: 19, success_rate: 0.240
#     │       │   │   ├── 6 success
#     │       │   │   └── 19 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 6, failure: 19, success_rate: 0.240
#     │       │   │   ├── 6 success
#     │       │   │   └── 19 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 9, failure: 16, success_rate: 0.360
#     │       │   │   ├── 9 success
#     │       │   │   └── 16 failure
#     │       │   └── None -> success: 10, failure: 15, success_rate: 0.400
#     │       │       ├── 10 success
#     │       │       └── 15 failure
#     │       └── google_robot_pick_coke_can_standing -> success: 57, failure: 43, success_rate: 0.570
#     │           ├── recolor_cabinet_visual_matching_1 -> success: 15, failure: 10, success_rate: 0.600
#     │           │   ├── 15 success
#     │           │   └── 10 failure
#     │           ├── recolor_tabletop_visual_matching_1 -> success: 13, failure: 12, success_rate: 0.520
#     │           │   ├── 13 success
#     │           │   └── 12 failure
#     │           ├── recolor_tabletop_visual_matching_2 -> success: 16, failure: 9, success_rate: 0.640
#     │           │   ├── 16 success
#     │           │   └── 9 failure
#     │           └── None -> success: 13, failure: 12, success_rate: 0.520
#     │               ├── 13 success
#     │               └── 12 failure
#     ├── rt_1_tf_trained_for_000001120 -> success: 10, failure: 290, success_rate: 0.033
#     │   └── google_robot_pick_coke_can -> success: 10, failure: 290, success_rate: 0.033
#     │       ├── google_robot_pick_coke_can_horizontally_laying -> success: 5, failure: 95, success_rate: 0.050
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 1, failure: 24, success_rate: 0.040
#     │       │   │   ├── 1 success
#     │       │   │   └── 24 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 25, success_rate: 0.000
#     │       │   │   └── 25 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 3, failure: 22, success_rate: 0.120
#     │       │   │   ├── 3 success
#     │       │   │   └── 22 failure
#     │       │   └── None -> success: 1, failure: 24, success_rate: 0.040
#     │       │       ├── 1 success
#     │       │       └── 24 failure
#     │       ├── google_robot_pick_coke_can_vertically_laying -> success: 0, failure: 100, success_rate: 0.000
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 25, success_rate: 0.000
#     │       │   │   └── 25 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 25, success_rate: 0.000
#     │       │   │   └── 25 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 25, success_rate: 0.000
#     │       │   │   └── 25 failure
#     │       │   └── None -> success: 0, failure: 25, success_rate: 0.000
#     │       │       └── 25 failure
#     │       └── google_robot_pick_coke_can_standing -> success: 5, failure: 95, success_rate: 0.050
#     │           ├── recolor_cabinet_visual_matching_1 -> success: 1, failure: 24, success_rate: 0.040
#     │           │   ├── 1 success
#     │           │   └── 24 failure
#     │           ├── recolor_tabletop_visual_matching_1 -> success: 1, failure: 24, success_rate: 0.040
#     │           │   ├── 1 success
#     │           │   └── 24 failure
#     │           ├── recolor_tabletop_visual_matching_2 -> success: 1, failure: 24, success_rate: 0.040
#     │           │   ├── 1 success
#     │           │   └── 24 failure
#     │           └── None -> success: 2, failure: 23, success_rate: 0.080
#     │               ├── 2 success
#     │               └── 23 failure
#     └── octo-base -> success: 52, failure: 248, success_rate: 0.173
#         └── google_robot_pick_coke_can -> success: 52, failure: 248, success_rate: 0.173
#             ├── google_robot_pick_coke_can_horizontally_laying -> success: 16, failure: 84, success_rate: 0.160
#             │   ├── recolor_cabinet_visual_matching_1 -> success: 8, failure: 17, success_rate: 0.320
#             │   │   ├── 8 success
#             │   │   └── 17 failure
#             │   ├── recolor_tabletop_visual_matching_1 -> success: 6, failure: 19, success_rate: 0.240
#             │   │   ├── 6 success
#             │   │   └── 19 failure
#             │   ├── recolor_tabletop_visual_matching_2 -> success: 2, failure: 23, success_rate: 0.080
#             │   │   ├── 2 success
#             │   │   └── 23 failure
#             │   └── None -> success: 0, failure: 25, success_rate: 0.000
#             │       └── 25 failure
#             ├── google_robot_pick_coke_can_vertically_laying -> success: 25, failure: 75, success_rate: 0.250
#             │   ├── recolor_cabinet_visual_matching_1 -> success: 9, failure: 16, success_rate: 0.360
#             │   │   ├── 9 success
#             │   │   └── 16 failure
#             │   ├── recolor_tabletop_visual_matching_1 -> success: 10, failure: 15, success_rate: 0.400
#             │   │   ├── 10 success
#             │   │   └── 15 failure
#             │   ├── recolor_tabletop_visual_matching_2 -> success: 6, failure: 19, success_rate: 0.240
#             │   │   ├── 6 success
#             │   │   └── 19 failure
#             │   └── None -> success: 0, failure: 25, success_rate: 0.000
#             │       └── 25 failure
#             └── google_robot_pick_coke_can_standing -> success: 11, failure: 89, success_rate: 0.110
#                 ├── recolor_cabinet_visual_matching_1 -> success: 6, failure: 19, success_rate: 0.240
#                 │   ├── 6 success
#                 │   └── 19 failure
#                 ├── recolor_tabletop_visual_matching_1 -> success: 3, failure: 22, success_rate: 0.120
#                 │   ├── 3 success
#                 │   └── 22 failure
#                 ├── recolor_tabletop_visual_matching_2 -> success: 2, failure: 23, success_rate: 0.080
#                 │   ├── 2 success
#                 │   └── 23 failure
#                 └── None -> success: 0, failure: 25, success_rate: 0.000
#                     └── 25 failure

# %% [markdown]
# ### Build Tree for Move Near Task

# %%
move_task = [("MoveNearGoogleBakedTexInScene-v0", "google_robot_move_near")]
levels = [policies, move_task, urdf_versions, outcome]
_ , move_near_tree = build_tree("Eval Results For Move Near", levels, [])
print_tree(move_near_tree)
# Out:
# Eval Results For Move Near -> success: 291, failure: 909, success_rate: 0.242
# ├── rt_1_tf_trained_for_000400120 -> success: 98, failure: 142, success_rate: 0.408
# │   └── google_robot_move_near -> success: 98, failure: 142, success_rate: 0.408
# │       ├── recolor_cabinet_visual_matching_1 -> success: 26, failure: 34, success_rate: 0.433
# │       │   ├── 26 success
# │       │   └── 34 failure
# │       ├── recolor_tabletop_visual_matching_1 -> success: 25, failure: 35, success_rate: 0.417
# │       │   ├── 25 success
# │       │   └── 35 failure
# │       ├── recolor_tabletop_visual_matching_2 -> success: 25, failure: 35, success_rate: 0.417
# │       │   ├── 25 success
# │       │   └── 35 failure
# │       └── None -> success: 22, failure: 38, success_rate: 0.367
# │           ├── 22 success
# │           └── 38 failure
# ├── rt_1_tf_trained_for_000058240 -> success: 94, failure: 146, success_rate: 0.392
# │   └── google_robot_move_near -> success: 94, failure: 146, success_rate: 0.392
# │       ├── recolor_cabinet_visual_matching_1 -> success: 22, failure: 38, success_rate: 0.367
# │       │   ├── 22 success
# │       │   └── 38 failure
# │       ├── recolor_tabletop_visual_matching_1 -> success: 25, failure: 35, success_rate: 0.417
# │       │   ├── 25 success
# │       │   └── 35 failure
# │       ├── recolor_tabletop_visual_matching_2 -> success: 22, failure: 38, success_rate: 0.367
# │       │   ├── 22 success
# │       │   └── 38 failure
# │       └── None -> success: 25, failure: 35, success_rate: 0.417
# │           ├── 25 success
# │           └── 35 failure
# ├── rt_1_x_tf_trained_for_002272480_step -> success: 81, failure: 159, success_rate: 0.338
# │   └── google_robot_move_near -> success: 81, failure: 159, success_rate: 0.338
# │       ├── recolor_cabinet_visual_matching_1 -> success: 20, failure: 40, success_rate: 0.333
# │       │   ├── 20 success
# │       │   └── 40 failure
# │       ├── recolor_tabletop_visual_matching_1 -> success: 20, failure: 40, success_rate: 0.333
# │       │   ├── 20 success
# │       │   └── 40 failure
# │       ├── recolor_tabletop_visual_matching_2 -> success: 21, failure: 39, success_rate: 0.350
# │       │   ├── 21 success
# │       │   └── 39 failure
# │       └── None -> success: 20, failure: 40, success_rate: 0.333
# │           ├── 20 success
# │           └── 40 failure
# ├── rt_1_tf_trained_for_000001120 -> success: 8, failure: 232, success_rate: 0.033
# │   └── google_robot_move_near -> success: 8, failure: 232, success_rate: 0.033
# │       ├── recolor_cabinet_visual_matching_1 -> success: 1, failure: 59, success_rate: 0.017
# │       │   ├── 1 success
# │       │   └── 59 failure
# │       ├── recolor_tabletop_visual_matching_1 -> success: 2, failure: 58, success_rate: 0.033
# │       │   ├── 2 success
# │       │   └── 58 failure
# │       ├── recolor_tabletop_visual_matching_2 -> success: 3, failure: 57, success_rate: 0.050
# │       │   ├── 3 success
# │       │   └── 57 failure
# │       └── None -> success: 2, failure: 58, success_rate: 0.033
# │           ├── 2 success
# │           └── 58 failure
# └── octo-base -> success: 10, failure: 230, success_rate: 0.042
#     └── google_robot_move_near -> success: 10, failure: 230, success_rate: 0.042
#         ├── recolor_cabinet_visual_matching_1 -> success: 4, failure: 56, success_rate: 0.067
#         │   ├── 4 success
#         │   └── 56 failure
#         ├── recolor_tabletop_visual_matching_1 -> success: 2, failure: 58, success_rate: 0.033
#         │   ├── 2 success
#         │   └── 58 failure
#         ├── recolor_tabletop_visual_matching_2 -> success: 4, failure: 56, success_rate: 0.067
#         │   ├── 4 success
#         │   └── 56 failure
#         └── None -> success: 0, failure: 60, success_rate: 0.000
#             └── 60 failure

# %% [markdown]
# ### Build Tree for Place Tasks

# %%
place_task = [("PlaceIntoClosedTopDrawerCustomInScene-v0", "google_robot_place_apple_in_closed_top_drawer")]
levels = [policies, place_task, urdf_versions, outcome]
_ , place_apple_tree = build_tree("Eval Results For Place Apple in Closed Top Drawer", levels, [])
print_tree(place_apple_tree)
# Out:
# Eval Results For Place Apple in Closed Top Drawer -> success: 53, failure: 487, success_rate: 0.098
# ├── rt_1_tf_trained_for_000400120 -> success: 9, failure: 99, success_rate: 0.083
# │   └── google_robot_place_apple_in_closed_top_drawer -> success: 9, failure: 99, success_rate: 0.083
# │       ├── recolor_cabinet_visual_matching_1 -> success: 2, failure: 25, success_rate: 0.074
# │       │   ├── 2 success
# │       │   └── 25 failure
# │       ├── recolor_tabletop_visual_matching_1 -> success: 1, failure: 26, success_rate: 0.037
# │       │   ├── 1 success
# │       │   └── 26 failure
# │       ├── recolor_tabletop_visual_matching_2 -> success: 4, failure: 23, success_rate: 0.148
# │       │   ├── 4 success
# │       │   └── 23 failure
# │       └── None -> success: 2, failure: 25, success_rate: 0.074
# │           ├── 2 success
# │           └── 25 failure
# ├── rt_1_tf_trained_for_000058240 -> success: 20, failure: 88, success_rate: 0.185
# │   └── google_robot_place_apple_in_closed_top_drawer -> success: 20, failure: 88, success_rate: 0.185
# │       ├── recolor_cabinet_visual_matching_1 -> success: 8, failure: 19, success_rate: 0.296
# │       │   ├── 8 success
# │       │   └── 19 failure
# │       ├── recolor_tabletop_visual_matching_1 -> success: 5, failure: 22, success_rate: 0.185
# │       │   ├── 5 success
# │       │   └── 22 failure
# │       ├── recolor_tabletop_visual_matching_2 -> success: 6, failure: 21, success_rate: 0.222
# │       │   ├── 6 success
# │       │   └── 21 failure
# │       └── None -> success: 1, failure: 26, success_rate: 0.037
# │           ├── 1 success
# │           └── 26 failure
# ├── rt_1_x_tf_trained_for_002272480_step -> success: 24, failure: 84, success_rate: 0.222
# │   └── google_robot_place_apple_in_closed_top_drawer -> success: 24, failure: 84, success_rate: 0.222
# │       ├── recolor_cabinet_visual_matching_1 -> success: 9, failure: 18, success_rate: 0.333
# │       │   ├── 9 success
# │       │   └── 18 failure
# │       ├── recolor_tabletop_visual_matching_1 -> success: 8, failure: 19, success_rate: 0.296
# │       │   ├── 8 success
# │       │   └── 19 failure
# │       ├── recolor_tabletop_visual_matching_2 -> success: 5, failure: 22, success_rate: 0.185
# │       │   ├── 5 success
# │       │   └── 22 failure
# │       └── None -> success: 2, failure: 25, success_rate: 0.074
# │           ├── 2 success
# │           └── 25 failure
# ├── rt_1_tf_trained_for_000001120 -> success: 0, failure: 108, success_rate: 0.000
# │   └── google_robot_place_apple_in_closed_top_drawer -> success: 0, failure: 108, success_rate: 0.000
# │       ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 27, success_rate: 0.000
# │       │   └── 27 failure
# │       ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 27, success_rate: 0.000
# │       │   └── 27 failure
# │       ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 27, success_rate: 0.000
# │       │   └── 27 failure
# │       └── None -> success: 0, failure: 27, success_rate: 0.000
# │           └── 27 failure
# └── octo-base -> success: 0, failure: 108, success_rate: 0.000
#     └── google_robot_place_apple_in_closed_top_drawer -> success: 0, failure: 108, success_rate: 0.000
#         ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 27, success_rate: 0.000
#         │   └── 27 failure
#         ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 27, success_rate: 0.000
#         │   └── 27 failure
#         ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 27, success_rate: 0.000
#         │   └── 27 failure
#         └── None -> success: 0, failure: 27, success_rate: 0.000
#             └── 27 failure

# %% [markdown]
# ### Node Lookup for Tree

# %%
# Define the regex patterns to traverse the tree.
#patterns = ["rt_1_tf_trained_for_000400120", "Open(?:Bottom|Top|Middle)Drawer", "OpenTopDrawerCustomInScene-v0"]
patterns = ["octo-base", "google_robot_open_drawer", "OpenTopDrawerCustomInScene-v0"]

node = get_node(drawer_tree, patterns)
print(node.name, "\nSuccess:", node.success, "\nFailure:", node.failure, "\nSuccess Rate", node.success_rate)
print_tree(node)
# Out:
# OpenTopDrawerCustomInScene-v0
# Success: 0
# Failure: 36
# Success Rate 0.0
# OpenTopDrawerCustomInScene-v0 -> success: 0, failure: 36, success_rate: 0.000
# ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 9, success_rate: 0.000
# │   └── 9 failure
# ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 9, success_rate: 0.000
# │   └── 9 failure
# ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 9, success_rate: 0.000
# │   └── 9 failure
# └── None -> success: 0, failure: 9, success_rate: 0.000
#     └── 9 failure

# %% [markdown]
# ### Build Task Trees for New Tasks

# %%
move_task = [("MoveNearGoogleBakedTexInSceneNew-v0", "google_robot_move_near")]
levels = [scenes[:1], policies, move_task, urdf_versions, outcome]
_ , move_near_tabletop_tree = build_tree("Eval Results For Move Near", levels, [])
print_tree(move_near_tabletop_tree)

levels = [scenes[1:], policies, move_task, urdf_versions, outcome]
_ , move_near_wood_tree = build_tree("Eval Results For Move Near", levels, [])
print_tree(move_near_wood_tree)
# Out:
# Eval Results For Move Near -> success: 323, failure: 877, success_rate: 0.269
# └── dummy_tabletop1 -> success: 323, failure: 877, success_rate: 0.269
#     ├── rt_1_tf_trained_for_000400120 -> success: 137, failure: 103, success_rate: 0.571
#     │   └── google_robot_move_near -> success: 137, failure: 103, success_rate: 0.571
#     │       ├── recolor_cabinet_visual_matching_1 -> success: 35, failure: 25, success_rate: 0.583
#     │       │   ├── 35 success
#     │       │   └── 25 failure
#     │       ├── recolor_tabletop_visual_matching_1 -> success: 35, failure: 25, success_rate: 0.583
#     │       │   ├── 35 success
#     │       │   └── 25 failure
#     │       ├── recolor_tabletop_visual_matching_2 -> success: 36, failure: 24, success_rate: 0.600
#     │       │   ├── 36 success
#     │       │   └── 24 failure
#     │       └── None -> success: 31, failure: 29, success_rate: 0.517
#     │           ├── 31 success
#     │           └── 29 failure
#     ├── rt_1_tf_trained_for_000058240 -> success: 106, failure: 134, success_rate: 0.442
#     │   └── google_robot_move_near -> success: 106, failure: 134, success_rate: 0.442
#     │       ├── recolor_cabinet_visual_matching_1 -> success: 25, failure: 35, success_rate: 0.417
#     │       │   ├── 25 success
#     │       │   └── 35 failure
#     │       ├── recolor_tabletop_visual_matching_1 -> success: 28, failure: 32, success_rate: 0.467
#     │       │   ├── 28 success
#     │       │   └── 32 failure
#     │       ├── recolor_tabletop_visual_matching_2 -> success: 30, failure: 30, success_rate: 0.500
#     │       │   ├── 30 success
#     │       │   └── 30 failure
#     │       └── None -> success: 23, failure: 37, success_rate: 0.383
#     │           ├── 23 success
#     │           └── 37 failure
#     ├── rt_1_x_tf_trained_for_002272480_step -> success: 58, failure: 182, success_rate: 0.242
#     │   └── google_robot_move_near -> success: 58, failure: 182, success_rate: 0.242
#     │       ├── recolor_cabinet_visual_matching_1 -> success: 14, failure: 46, success_rate: 0.233
#     │       │   ├── 14 success
#     │       │   └── 46 failure
#     │       ├── recolor_tabletop_visual_matching_1 -> success: 18, failure: 42, success_rate: 0.300
#     │       │   ├── 18 success
#     │       │   └── 42 failure
#     │       ├── recolor_tabletop_visual_matching_2 -> success: 16, failure: 44, success_rate: 0.267
#     │       │   ├── 16 success
#     │       │   └── 44 failure
#     │       └── None -> success: 10, failure: 50, success_rate: 0.167
#     │           ├── 10 success
#     │           └── 50 failure
#     ├── rt_1_tf_trained_for_000001120 -> success: 4, failure: 236, success_rate: 0.017
#     │   └── google_robot_move_near -> success: 4, failure: 236, success_rate: 0.017
#     │       ├── recolor_cabinet_visual_matching_1 -> success: 1, failure: 59, success_rate: 0.017
#     │       │   ├── 1 success
#     │       │   └── 59 failure
#     │       ├── recolor_tabletop_visual_matching_1 -> success: 2, failure: 58, success_rate: 0.033
#     │       │   ├── 2 success
#     │       │   └── 58 failure
#     │       ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 60, success_rate: 0.000
#     │       │   └── 60 failure
#     │       └── None -> success: 1, failure: 59, success_rate: 0.017
#     │           ├── 1 success
#     │           └── 59 failure
#     └── octo-base -> success: 18, failure: 222, success_rate: 0.075
#         └── google_robot_move_near -> success: 18, failure: 222, success_rate: 0.075
#             ├── recolor_cabinet_visual_matching_1 -> success: 5, failure: 55, success_rate: 0.083
#             │   ├── 5 success
#             │   └── 55 failure
#             ├── recolor_tabletop_visual_matching_1 -> success: 4, failure: 56, success_rate: 0.067
#             │   ├── 4 success
#             │   └── 56 failure
#             ├── recolor_tabletop_visual_matching_2 -> success: 5, failure: 55, success_rate: 0.083
#             │   ├── 5 success
#             │   └── 55 failure
#             └── None -> success: 4, failure: 56, success_rate: 0.067
#                 ├── 4 success
#                 └── 56 failure
# Eval Results For Move Near -> success: 278, failure: 922, success_rate: 0.232
# └── dummy_wood_tabletop -> success: 278, failure: 922, success_rate: 0.232
#     ├── rt_1_tf_trained_for_000400120 -> success: 107, failure: 133, success_rate: 0.446
#     │   └── google_robot_move_near -> success: 107, failure: 133, success_rate: 0.446
#     │       ├── recolor_cabinet_visual_matching_1 -> success: 29, failure: 31, success_rate: 0.483
#     │       │   ├── 29 success
#     │       │   └── 31 failure
#     │       ├── recolor_tabletop_visual_matching_1 -> success: 28, failure: 32, success_rate: 0.467
#     │       │   ├── 28 success
#     │       │   └── 32 failure
#     │       ├── recolor_tabletop_visual_matching_2 -> success: 30, failure: 30, success_rate: 0.500
#     │       │   ├── 30 success
#     │       │   └── 30 failure
#     │       └── None -> success: 20, failure: 40, success_rate: 0.333
#     │           ├── 20 success
#     │           └── 40 failure
#     ├── rt_1_tf_trained_for_000058240 -> success: 90, failure: 150, success_rate: 0.375
#     │   └── google_robot_move_near -> success: 90, failure: 150, success_rate: 0.375
#     │       ├── recolor_cabinet_visual_matching_1 -> success: 27, failure: 33, success_rate: 0.450
#     │       │   ├── 27 success
#     │       │   └── 33 failure
#     │       ├── recolor_tabletop_visual_matching_1 -> success: 25, failure: 35, success_rate: 0.417
#     │       │   ├── 25 success
#     │       │   └── 35 failure
#     │       ├── recolor_tabletop_visual_matching_2 -> success: 24, failure: 36, success_rate: 0.400
#     │       │   ├── 24 success
#     │       │   └── 36 failure
#     │       └── None -> success: 14, failure: 46, success_rate: 0.233
#     │           ├── 14 success
#     │           └── 46 failure
#     ├── rt_1_x_tf_trained_for_002272480_step -> success: 66, failure: 174, success_rate: 0.275
#     │   └── google_robot_move_near -> success: 66, failure: 174, success_rate: 0.275
#     │       ├── recolor_cabinet_visual_matching_1 -> success: 19, failure: 41, success_rate: 0.317
#     │       │   ├── 19 success
#     │       │   └── 41 failure
#     │       ├── recolor_tabletop_visual_matching_1 -> success: 17, failure: 43, success_rate: 0.283
#     │       │   ├── 17 success
#     │       │   └── 43 failure
#     │       ├── recolor_tabletop_visual_matching_2 -> success: 13, failure: 47, success_rate: 0.217
#     │       │   ├── 13 success
#     │       │   └── 47 failure
#     │       └── None -> success: 17, failure: 43, success_rate: 0.283
#     │           ├── 17 success
#     │           └── 43 failure
#     ├── rt_1_tf_trained_for_000001120 -> success: 10, failure: 230, success_rate: 0.042
#     │   └── google_robot_move_near -> success: 10, failure: 230, success_rate: 0.042
#     │       ├── recolor_cabinet_visual_matching_1 -> success: 2, failure: 58, success_rate: 0.033
#     │       │   ├── 2 success
#     │       │   └── 58 failure
#     │       ├── recolor_tabletop_visual_matching_1 -> success: 1, failure: 59, success_rate: 0.017
#     │       │   ├── 1 success
#     │       │   └── 59 failure
#     │       ├── recolor_tabletop_visual_matching_2 -> success: 6, failure: 54, success_rate: 0.100
#     │       │   ├── 6 success
#     │       │   └── 54 failure
#     │       └── None -> success: 1, failure: 59, success_rate: 0.017
#     │           ├── 1 success
#     │           └── 59 failure
#     └── octo-base -> success: 5, failure: 235, success_rate: 0.021
#         └── google_robot_move_near -> success: 5, failure: 235, success_rate: 0.021
#             ├── recolor_cabinet_visual_matching_1 -> success: 1, failure: 59, success_rate: 0.017
#             │   ├── 1 success
#             │   └── 59 failure
#             ├── recolor_tabletop_visual_matching_1 -> success: 1, failure: 59, success_rate: 0.017
#             │   ├── 1 success
#             │   └── 59 failure
#             ├── recolor_tabletop_visual_matching_2 -> success: 1, failure: 59, success_rate: 0.017
#             │   ├── 1 success
#             │   └── 59 failure
#             └── None -> success: 2, failure: 58, success_rate: 0.033
#                 ├── 2 success
#                 └── 58 failure

# %%
move_to_number_task = [("PutOnNumberGoogleInScene-v0", "google_robot_move_to_number"),
                       ("PutOnNumberSumGoogleInScene-v0", "google_robot_move_to_number_sum"),
                       ("PutOnNumberMultGoogleInScene-v0", "google_robot_move_to_number_mult"),
                       ("PutOnNumberSmallestGoogleInScene-v0", "google_robot_move_to_number_smallest")]
average_level = [(r"PutOnNumber(?:Sum|Smallest|Mult)?GoogleInScene-v0", "google_robot_move_to_number_avg")]
levels = [policies, average_level, move_to_number_task, urdf_versions, outcome]
_ , move_to_number_tree = build_tree("Eval Results Move to Number", levels, [])
print_tree(move_to_number_tree)
# Out:
# Eval Results Move to Number -> success: 21, failure: 2131, success_rate: 0.010
# ├── rt_1_tf_trained_for_000400120 -> success: 1, failure: 383, success_rate: 0.003
# │   └── google_robot_move_to_number_avg -> success: 1, failure: 383, success_rate: 0.003
# │       ├── google_robot_move_to_number -> success: 1, failure: 95, success_rate: 0.010
# │       │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_2 -> success: 1, failure: 23, success_rate: 0.042
# │       │   │   ├── 1 success
# │       │   │   └── 23 failure
# │       │   └── None -> success: 0, failure: 24, success_rate: 0.000
# │       │       └── 24 failure
# │       ├── google_robot_move_to_number_sum -> success: 0, failure: 96, success_rate: 0.000
# │       │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   └── None -> success: 0, failure: 24, success_rate: 0.000
# │       │       └── 24 failure
# │       ├── google_robot_move_to_number_mult -> success: 0, failure: 96, success_rate: 0.000
# │       │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   └── None -> success: 0, failure: 24, success_rate: 0.000
# │       │       └── 24 failure
# │       └── google_robot_move_to_number_smallest -> success: 0, failure: 96, success_rate: 0.000
# │           ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │           │   └── 24 failure
# │           ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │           │   └── 24 failure
# │           ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 24, success_rate: 0.000
# │           │   └── 24 failure
# │           └── None -> success: 0, failure: 24, success_rate: 0.000
# │               └── 24 failure
# ├── rt_1_tf_trained_for_000058240 -> success: 0, failure: 384, success_rate: 0.000
# │   └── google_robot_move_to_number_avg -> success: 0, failure: 384, success_rate: 0.000
# │       ├── google_robot_move_to_number -> success: 0, failure: 96, success_rate: 0.000
# │       │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   └── None -> success: 0, failure: 24, success_rate: 0.000
# │       │       └── 24 failure
# │       ├── google_robot_move_to_number_sum -> success: 0, failure: 96, success_rate: 0.000
# │       │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   └── None -> success: 0, failure: 24, success_rate: 0.000
# │       │       └── 24 failure
# │       ├── google_robot_move_to_number_mult -> success: 0, failure: 96, success_rate: 0.000
# │       │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   └── None -> success: 0, failure: 24, success_rate: 0.000
# │       │       └── 24 failure
# │       └── google_robot_move_to_number_smallest -> success: 0, failure: 96, success_rate: 0.000
# │           ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │           │   └── 24 failure
# │           ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │           │   └── 24 failure
# │           ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 24, success_rate: 0.000
# │           │   └── 24 failure
# │           └── None -> success: 0, failure: 24, success_rate: 0.000
# │               └── 24 failure
# ├── rt_1_x_tf_trained_for_002272480_step -> success: 0, failure: 384, success_rate: 0.000
# │   └── google_robot_move_to_number_avg -> success: 0, failure: 384, success_rate: 0.000
# │       ├── google_robot_move_to_number -> success: 0, failure: 96, success_rate: 0.000
# │       │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   └── None -> success: 0, failure: 24, success_rate: 0.000
# │       │       └── 24 failure
# │       ├── google_robot_move_to_number_sum -> success: 0, failure: 96, success_rate: 0.000
# │       │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   └── None -> success: 0, failure: 24, success_rate: 0.000
# │       │       └── 24 failure
# │       ├── google_robot_move_to_number_mult -> success: 0, failure: 96, success_rate: 0.000
# │       │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   └── None -> success: 0, failure: 24, success_rate: 0.000
# │       │       └── 24 failure
# │       └── google_robot_move_to_number_smallest -> success: 0, failure: 96, success_rate: 0.000
# │           ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │           │   └── 24 failure
# │           ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │           │   └── 24 failure
# │           ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 24, success_rate: 0.000
# │           │   └── 24 failure
# │           └── None -> success: 0, failure: 24, success_rate: 0.000
# │               └── 24 failure
# ├── rt_1_tf_trained_for_000001120 -> success: 6, failure: 354, success_rate: 0.017
# │   └── google_robot_move_to_number_avg -> success: 6, failure: 354, success_rate: 0.017
# │       ├── google_robot_move_to_number -> success: 0, failure: 96, success_rate: 0.000
# │       │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   └── None -> success: 0, failure: 24, success_rate: 0.000
# │       │       └── 24 failure
# │       ├── google_robot_move_to_number_sum -> success: 0, failure: 96, success_rate: 0.000
# │       │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   └── None -> success: 0, failure: 24, success_rate: 0.000
# │       │       └── 24 failure
# │       ├── google_robot_move_to_number_mult -> success: 0, failure: 72, success_rate: 0.000
# │       │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   └── None -> success: 0, failure: 24, success_rate: 0.000
# │       │       └── 24 failure
# │       └── google_robot_move_to_number_smallest -> success: 6, failure: 90, success_rate: 0.062
# │           ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │           │   └── 24 failure
# │           ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │           │   └── 24 failure
# │           ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 24, success_rate: 0.000
# │           │   └── 24 failure
# │           └── None -> success: 6, failure: 18, success_rate: 0.250
# │               ├── 6 success
# │               └── 18 failure
# ├── octo-base -> success: 7, failure: 377, success_rate: 0.018
# │   └── google_robot_move_to_number_avg -> success: 7, failure: 377, success_rate: 0.018
# │       ├── google_robot_move_to_number -> success: 4, failure: 92, success_rate: 0.042
# │       │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_1 -> success: 1, failure: 23, success_rate: 0.042
# │       │   │   ├── 1 success
# │       │   │   └── 23 failure
# │       │   ├── recolor_tabletop_visual_matching_2 -> success: 2, failure: 22, success_rate: 0.083
# │       │   │   ├── 2 success
# │       │   │   └── 22 failure
# │       │   └── None -> success: 1, failure: 23, success_rate: 0.042
# │       │       ├── 1 success
# │       │       └── 23 failure
# │       ├── google_robot_move_to_number_sum -> success: 1, failure: 95, success_rate: 0.010
# │       │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_2 -> success: 1, failure: 23, success_rate: 0.042
# │       │   │   ├── 1 success
# │       │   │   └── 23 failure
# │       │   └── None -> success: 0, failure: 24, success_rate: 0.000
# │       │       └── 24 failure
# │       ├── google_robot_move_to_number_mult -> success: 0, failure: 96, success_rate: 0.000
# │       │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 24, success_rate: 0.000
# │       │   │   └── 24 failure
# │       │   └── None -> success: 0, failure: 24, success_rate: 0.000
# │       │       └── 24 failure
# │       └── google_robot_move_to_number_smallest -> success: 2, failure: 94, success_rate: 0.021
# │           ├── recolor_cabinet_visual_matching_1 -> success: 1, failure: 23, success_rate: 0.042
# │           │   ├── 1 success
# │           │   └── 23 failure
# │           ├── recolor_tabletop_visual_matching_1 -> success: 1, failure: 23, success_rate: 0.042
# │           │   ├── 1 success
# │           │   └── 23 failure
# │           ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 24, success_rate: 0.000
# │           │   └── 24 failure
# │           └── None -> success: 0, failure: 24, success_rate: 0.000
# │               └── 24 failure
# └── openvla-7b -> success: 7, failure: 249, success_rate: 0.027
#     └── google_robot_move_to_number_avg -> success: 7, failure: 249, success_rate: 0.027
#         ├── google_robot_move_to_number -> success: 1, failure: 95, success_rate: 0.010
#         │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
#         │   │   └── 24 failure
#         │   ├── recolor_tabletop_visual_matching_1 -> success: 1, failure: 23, success_rate: 0.042
#         │   │   ├── 1 success
#         │   │   └── 23 failure
#         │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 24, success_rate: 0.000
#         │   │   └── 24 failure
#         │   └── None -> success: 0, failure: 24, success_rate: 0.000
#         │       └── 24 failure
#         ├── google_robot_move_to_number_sum -> success: 0, failure: 32, success_rate: 0.000
#         │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 8, success_rate: 0.000
#         │   │   └── 8 failure
#         │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 8, success_rate: 0.000
#         │   │   └── 8 failure
#         │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 8, success_rate: 0.000
#         │   │   └── 8 failure
#         │   └── None -> success: 0, failure: 8, success_rate: 0.000
#         │       └── 8 failure
#         ├── google_robot_move_to_number_mult -> success: 3, failure: 29, success_rate: 0.094
#         │   ├── recolor_cabinet_visual_matching_1 -> success: 1, failure: 7, success_rate: 0.125
#         │   │   ├── 1 success
#         │   │   └── 7 failure
#         │   ├── recolor_tabletop_visual_matching_1 -> success: 2, failure: 6, success_rate: 0.250
#         │   │   ├── 2 success
#         │   │   └── 6 failure
#         │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 8, success_rate: 0.000
#         │   │   └── 8 failure
#         │   └── None -> success: 0, failure: 8, success_rate: 0.000
#         │       └── 8 failure
#         └── google_robot_move_to_number_smallest -> success: 3, failure: 93, success_rate: 0.031
#             ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
#             │   └── 24 failure
#             ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 24, success_rate: 0.000
#             │   └── 24 failure
#             ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 24, success_rate: 0.000
#             │   └── 24 failure
#             └── None -> success: 3, failure: 21, success_rate: 0.125
#                 ├── 3 success
#                 └── 21 failure

# %%
orientation_tasks = [("lr_switch_True", "google_robot_pick_coke_can_horizontally_laying"), 
                     ("laid_vertically_True", "google_robot_pick_coke_can_vertically_laying"), 
                     ("upright_True", "google_robot_pick_coke_can_standing")]

#Note tuple for renaming purposes
pick_task= [("GraspSingleOpenedCokeCanInScene-v0", "google_robot_pick_coke_can")]
levels = [scenes[:1], policies, pick_task, orientation_tasks, urdf_versions, outcome]
_ , pick_coke_can_tabletop_tree = build_tree("Eval Results For Pick Coke Can (Tabletop)", levels, [])
print_tree(pick_coke_can_tabletop_tree)

levels = [scenes[1:], policies, pick_task, orientation_tasks, urdf_versions, outcome]
_ , pick_coke_can_wood_tree = build_tree("Eval Results For Pick Coke Can (Wooden Tabletop)", levels, [])
print_tree(pick_coke_can_wood_tree)
# Out:
# Eval Results For Pick Coke Can (Tabletop) -> success: 657, failure: 1039, success_rate: 0.387
# └── dummy_tabletop1 -> success: 657, failure: 1039, success_rate: 0.387
#     ├── rt_1_tf_trained_for_000400120 -> success: 232, failure: 68, success_rate: 0.773
#     │   └── google_robot_pick_coke_can -> success: 232, failure: 68, success_rate: 0.773
#     │       ├── google_robot_pick_coke_can_horizontally_laying -> success: 64, failure: 36, success_rate: 0.640
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 16, failure: 9, success_rate: 0.640
#     │       │   │   ├── 16 success
#     │       │   │   └── 9 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 17, failure: 8, success_rate: 0.680
#     │       │   │   ├── 17 success
#     │       │   │   └── 8 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 15, failure: 10, success_rate: 0.600
#     │       │   │   ├── 15 success
#     │       │   │   └── 10 failure
#     │       │   └── None -> success: 16, failure: 9, success_rate: 0.640
#     │       │       ├── 16 success
#     │       │       └── 9 failure
#     │       ├── google_robot_pick_coke_can_vertically_laying -> success: 68, failure: 32, success_rate: 0.680
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 19, failure: 6, success_rate: 0.760
#     │       │   │   ├── 19 success
#     │       │   │   └── 6 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 18, failure: 7, success_rate: 0.720
#     │       │   │   ├── 18 success
#     │       │   │   └── 7 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 14, failure: 11, success_rate: 0.560
#     │       │   │   ├── 14 success
#     │       │   │   └── 11 failure
#     │       │   └── None -> success: 17, failure: 8, success_rate: 0.680
#     │       │       ├── 17 success
#     │       │       └── 8 failure
#     │       └── google_robot_pick_coke_can_standing -> success: 100, failure: 0, success_rate: 1.000
#     │           ├── recolor_cabinet_visual_matching_1 -> success: 25, failure: 0, success_rate: 1.000
#     │           │   └── 25 success
#     │           ├── recolor_tabletop_visual_matching_1 -> success: 25, failure: 0, success_rate: 1.000
#     │           │   └── 25 success
#     │           ├── recolor_tabletop_visual_matching_2 -> success: 25, failure: 0, success_rate: 1.000
#     │           │   └── 25 success
#     │           └── None -> success: 25, failure: 0, success_rate: 1.000
#     │               └── 25 success
#     ├── rt_1_tf_trained_for_000058240 -> success: 198, failure: 102, success_rate: 0.660
#     │   └── google_robot_pick_coke_can -> success: 198, failure: 102, success_rate: 0.660
#     │       ├── google_robot_pick_coke_can_horizontally_laying -> success: 62, failure: 38, success_rate: 0.620
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 21, failure: 4, success_rate: 0.840
#     │       │   │   ├── 21 success
#     │       │   │   └── 4 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 13, failure: 12, success_rate: 0.520
#     │       │   │   ├── 13 success
#     │       │   │   └── 12 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 17, failure: 8, success_rate: 0.680
#     │       │   │   ├── 17 success
#     │       │   │   └── 8 failure
#     │       │   └── None -> success: 11, failure: 14, success_rate: 0.440
#     │       │       ├── 11 success
#     │       │       └── 14 failure
#     │       ├── google_robot_pick_coke_can_vertically_laying -> success: 61, failure: 39, success_rate: 0.610
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 15, failure: 10, success_rate: 0.600
#     │       │   │   ├── 15 success
#     │       │   │   └── 10 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 16, failure: 9, success_rate: 0.640
#     │       │   │   ├── 16 success
#     │       │   │   └── 9 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 16, failure: 9, success_rate: 0.640
#     │       │   │   ├── 16 success
#     │       │   │   └── 9 failure
#     │       │   └── None -> success: 14, failure: 11, success_rate: 0.560
#     │       │       ├── 14 success
#     │       │       └── 11 failure
#     │       └── google_robot_pick_coke_can_standing -> success: 75, failure: 25, success_rate: 0.750
#     │           ├── recolor_cabinet_visual_matching_1 -> success: 17, failure: 8, success_rate: 0.680
#     │           │   ├── 17 success
#     │           │   └── 8 failure
#     │           ├── recolor_tabletop_visual_matching_1 -> success: 20, failure: 5, success_rate: 0.800
#     │           │   ├── 20 success
#     │           │   └── 5 failure
#     │           ├── recolor_tabletop_visual_matching_2 -> success: 19, failure: 6, success_rate: 0.760
#     │           │   ├── 19 success
#     │           │   └── 6 failure
#     │           └── None -> success: 19, failure: 6, success_rate: 0.760
#     │               ├── 19 success
#     │               └── 6 failure
#     ├── rt_1_x_tf_trained_for_002272480_step -> success: 157, failure: 143, success_rate: 0.523
#     │   └── google_robot_pick_coke_can -> success: 157, failure: 143, success_rate: 0.523
#     │       ├── google_robot_pick_coke_can_horizontally_laying -> success: 53, failure: 47, success_rate: 0.530
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 14, failure: 11, success_rate: 0.560
#     │       │   │   ├── 14 success
#     │       │   │   └── 11 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 12, failure: 13, success_rate: 0.480
#     │       │   │   ├── 12 success
#     │       │   │   └── 13 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 13, failure: 12, success_rate: 0.520
#     │       │   │   ├── 13 success
#     │       │   │   └── 12 failure
#     │       │   └── None -> success: 14, failure: 11, success_rate: 0.560
#     │       │       ├── 14 success
#     │       │       └── 11 failure
#     │       ├── google_robot_pick_coke_can_vertically_laying -> success: 29, failure: 71, success_rate: 0.290
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 9, failure: 16, success_rate: 0.360
#     │       │   │   ├── 9 success
#     │       │   │   └── 16 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 8, failure: 17, success_rate: 0.320
#     │       │   │   ├── 8 success
#     │       │   │   └── 17 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 8, failure: 17, success_rate: 0.320
#     │       │   │   ├── 8 success
#     │       │   │   └── 17 failure
#     │       │   └── None -> success: 4, failure: 21, success_rate: 0.160
#     │       │       ├── 4 success
#     │       │       └── 21 failure
#     │       └── google_robot_pick_coke_can_standing -> success: 75, failure: 25, success_rate: 0.750
#     │           ├── recolor_cabinet_visual_matching_1 -> success: 19, failure: 6, success_rate: 0.760
#     │           │   ├── 19 success
#     │           │   └── 6 failure
#     │           ├── recolor_tabletop_visual_matching_1 -> success: 18, failure: 7, success_rate: 0.720
#     │           │   ├── 18 success
#     │           │   └── 7 failure
#     │           ├── recolor_tabletop_visual_matching_2 -> success: 18, failure: 7, success_rate: 0.720
#     │           │   ├── 18 success
#     │           │   └── 7 failure
#     │           └── None -> success: 20, failure: 5, success_rate: 0.800
#     │               ├── 20 success
#     │               └── 5 failure
#     ├── rt_1_tf_trained_for_000001120 -> success: 7, failure: 293, success_rate: 0.023
#     │   └── google_robot_pick_coke_can -> success: 7, failure: 293, success_rate: 0.023
#     │       ├── google_robot_pick_coke_can_horizontally_laying -> success: 5, failure: 95, success_rate: 0.050
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 2, failure: 23, success_rate: 0.080
#     │       │   │   ├── 2 success
#     │       │   │   └── 23 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 25, success_rate: 0.000
#     │       │   │   └── 25 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 3, failure: 22, success_rate: 0.120
#     │       │   │   ├── 3 success
#     │       │   │   └── 22 failure
#     │       │   └── None -> success: 0, failure: 25, success_rate: 0.000
#     │       │       └── 25 failure
#     │       ├── google_robot_pick_coke_can_vertically_laying -> success: 0, failure: 100, success_rate: 0.000
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 25, success_rate: 0.000
#     │       │   │   └── 25 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 25, success_rate: 0.000
#     │       │   │   └── 25 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 25, success_rate: 0.000
#     │       │   │   └── 25 failure
#     │       │   └── None -> success: 0, failure: 25, success_rate: 0.000
#     │       │       └── 25 failure
#     │       └── google_robot_pick_coke_can_standing -> success: 2, failure: 98, success_rate: 0.020
#     │           ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 25, success_rate: 0.000
#     │           │   └── 25 failure
#     │           ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 25, success_rate: 0.000
#     │           │   └── 25 failure
#     │           ├── recolor_tabletop_visual_matching_2 -> success: 2, failure: 23, success_rate: 0.080
#     │           │   ├── 2 success
#     │           │   └── 23 failure
#     │           └── None -> success: 0, failure: 25, success_rate: 0.000
#     │               └── 25 failure
#     ├── octo-base -> success: 32, failure: 268, success_rate: 0.107
#     │   └── google_robot_pick_coke_can -> success: 32, failure: 268, success_rate: 0.107
#     │       ├── google_robot_pick_coke_can_horizontally_laying -> success: 7, failure: 93, success_rate: 0.070
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 3, failure: 22, success_rate: 0.120
#     │       │   │   ├── 3 success
#     │       │   │   └── 22 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 2, failure: 23, success_rate: 0.080
#     │       │   │   ├── 2 success
#     │       │   │   └── 23 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 2, failure: 23, success_rate: 0.080
#     │       │   │   ├── 2 success
#     │       │   │   └── 23 failure
#     │       │   └── None -> success: 0, failure: 25, success_rate: 0.000
#     │       │       └── 25 failure
#     │       ├── google_robot_pick_coke_can_vertically_laying -> success: 8, failure: 92, success_rate: 0.080
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 2, failure: 23, success_rate: 0.080
#     │       │   │   ├── 2 success
#     │       │   │   └── 23 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 3, failure: 22, success_rate: 0.120
#     │       │   │   ├── 3 success
#     │       │   │   └── 22 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 2, failure: 23, success_rate: 0.080
#     │       │   │   ├── 2 success
#     │       │   │   └── 23 failure
#     │       │   └── None -> success: 1, failure: 24, success_rate: 0.040
#     │       │       ├── 1 success
#     │       │       └── 24 failure
#     │       └── google_robot_pick_coke_can_standing -> success: 17, failure: 83, success_rate: 0.170
#     │           ├── recolor_cabinet_visual_matching_1 -> success: 6, failure: 19, success_rate: 0.240
#     │           │   ├── 6 success
#     │           │   └── 19 failure
#     │           ├── recolor_tabletop_visual_matching_1 -> success: 5, failure: 20, success_rate: 0.200
#     │           │   ├── 5 success
#     │           │   └── 20 failure
#     │           ├── recolor_tabletop_visual_matching_2 -> success: 5, failure: 20, success_rate: 0.200
#     │           │   ├── 5 success
#     │           │   └── 20 failure
#     │           └── None -> success: 1, failure: 24, success_rate: 0.040
#     │               ├── 1 success
#     │               └── 24 failure
#     └── openvla-7b -> success: 31, failure: 165, success_rate: 0.158
#         └── google_robot_pick_coke_can -> success: 31, failure: 165, success_rate: 0.158
#             ├── google_robot_pick_coke_can_horizontally_laying -> success: 18, failure: 55, success_rate: 0.247
#             │   ├── recolor_tabletop_visual_matching_1 -> success: 9, failure: 16, success_rate: 0.360
#             │   │   ├── 9 success
#             │   │   └── 16 failure
#             │   ├── recolor_tabletop_visual_matching_2 -> success: 3, failure: 20, success_rate: 0.130
#             │   │   ├── 3 success
#             │   │   └── 20 failure
#             │   └── None -> success: 6, failure: 19, success_rate: 0.240
#             │       ├── 6 success
#             │       └── 19 failure
#             ├── google_robot_pick_coke_can_vertically_laying -> success: 0, failure: 50, success_rate: 0.000
#             │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 25, success_rate: 0.000
#             │   │   └── 25 failure
#             │   └── None -> success: 0, failure: 25, success_rate: 0.000
#             │       └── 25 failure
#             └── google_robot_pick_coke_can_standing -> success: 13, failure: 60, success_rate: 0.178
#                 ├── recolor_tabletop_visual_matching_1 -> success: 4, failure: 21, success_rate: 0.160
#                 │   ├── 4 success
#                 │   └── 21 failure
#                 ├── recolor_tabletop_visual_matching_2 -> success: 3, failure: 20, success_rate: 0.130
#                 │   ├── 3 success
#                 │   └── 20 failure
#                 └── None -> success: 6, failure: 19, success_rate: 0.240
#                     ├── 6 success
#                     └── 19 failure
# Eval Results For Pick Coke Can (Wooden Tabletop) -> success: 662, failure: 1138, success_rate: 0.368
# └── dummy_wood_tabletop -> success: 662, failure: 1138, success_rate: 0.368
#     ├── rt_1_tf_trained_for_000400120 -> success: 219, failure: 81, success_rate: 0.730
#     │   └── google_robot_pick_coke_can -> success: 219, failure: 81, success_rate: 0.730
#     │       ├── google_robot_pick_coke_can_horizontally_laying -> success: 71, failure: 29, success_rate: 0.710
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 22, failure: 3, success_rate: 0.880
#     │       │   │   ├── 22 success
#     │       │   │   └── 3 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 15, failure: 10, success_rate: 0.600
#     │       │   │   ├── 15 success
#     │       │   │   └── 10 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 14, failure: 11, success_rate: 0.560
#     │       │   │   ├── 14 success
#     │       │   │   └── 11 failure
#     │       │   └── None -> success: 20, failure: 5, success_rate: 0.800
#     │       │       ├── 20 success
#     │       │       └── 5 failure
#     │       ├── google_robot_pick_coke_can_vertically_laying -> success: 59, failure: 41, success_rate: 0.590
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 21, failure: 4, success_rate: 0.840
#     │       │   │   ├── 21 success
#     │       │   │   └── 4 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 19, failure: 6, success_rate: 0.760
#     │       │   │   ├── 19 success
#     │       │   │   └── 6 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 10, failure: 15, success_rate: 0.400
#     │       │   │   ├── 10 success
#     │       │   │   └── 15 failure
#     │       │   └── None -> success: 9, failure: 16, success_rate: 0.360
#     │       │       ├── 9 success
#     │       │       └── 16 failure
#     │       └── google_robot_pick_coke_can_standing -> success: 89, failure: 11, success_rate: 0.890
#     │           ├── recolor_cabinet_visual_matching_1 -> success: 22, failure: 3, success_rate: 0.880
#     │           │   ├── 22 success
#     │           │   └── 3 failure
#     │           ├── recolor_tabletop_visual_matching_1 -> success: 22, failure: 3, success_rate: 0.880
#     │           │   ├── 22 success
#     │           │   └── 3 failure
#     │           ├── recolor_tabletop_visual_matching_2 -> success: 23, failure: 2, success_rate: 0.920
#     │           │   ├── 23 success
#     │           │   └── 2 failure
#     │           └── None -> success: 22, failure: 3, success_rate: 0.880
#     │               ├── 22 success
#     │               └── 3 failure
#     ├── rt_1_tf_trained_for_000058240 -> success: 153, failure: 147, success_rate: 0.510
#     │   └── google_robot_pick_coke_can -> success: 153, failure: 147, success_rate: 0.510
#     │       ├── google_robot_pick_coke_can_horizontally_laying -> success: 45, failure: 55, success_rate: 0.450
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 16, failure: 9, success_rate: 0.640
#     │       │   │   ├── 16 success
#     │       │   │   └── 9 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 14, failure: 11, success_rate: 0.560
#     │       │   │   ├── 14 success
#     │       │   │   └── 11 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 8, failure: 17, success_rate: 0.320
#     │       │   │   ├── 8 success
#     │       │   │   └── 17 failure
#     │       │   └── None -> success: 7, failure: 18, success_rate: 0.280
#     │       │       ├── 7 success
#     │       │       └── 18 failure
#     │       ├── google_robot_pick_coke_can_vertically_laying -> success: 37, failure: 63, success_rate: 0.370
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 13, failure: 12, success_rate: 0.520
#     │       │   │   ├── 13 success
#     │       │   │   └── 12 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 8, failure: 17, success_rate: 0.320
#     │       │   │   ├── 8 success
#     │       │   │   └── 17 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 6, failure: 19, success_rate: 0.240
#     │       │   │   ├── 6 success
#     │       │   │   └── 19 failure
#     │       │   └── None -> success: 10, failure: 15, success_rate: 0.400
#     │       │       ├── 10 success
#     │       │       └── 15 failure
#     │       └── google_robot_pick_coke_can_standing -> success: 71, failure: 29, success_rate: 0.710
#     │           ├── recolor_cabinet_visual_matching_1 -> success: 17, failure: 8, success_rate: 0.680
#     │           │   ├── 17 success
#     │           │   └── 8 failure
#     │           ├── recolor_tabletop_visual_matching_1 -> success: 19, failure: 6, success_rate: 0.760
#     │           │   ├── 19 success
#     │           │   └── 6 failure
#     │           ├── recolor_tabletop_visual_matching_2 -> success: 18, failure: 7, success_rate: 0.720
#     │           │   ├── 18 success
#     │           │   └── 7 failure
#     │           └── None -> success: 17, failure: 8, success_rate: 0.680
#     │               ├── 17 success
#     │               └── 8 failure
#     ├── rt_1_x_tf_trained_for_002272480_step -> success: 136, failure: 164, success_rate: 0.453
#     │   └── google_robot_pick_coke_can -> success: 136, failure: 164, success_rate: 0.453
#     │       ├── google_robot_pick_coke_can_horizontally_laying -> success: 50, failure: 50, success_rate: 0.500
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 14, failure: 11, success_rate: 0.560
#     │       │   │   ├── 14 success
#     │       │   │   └── 11 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 11, failure: 14, success_rate: 0.440
#     │       │   │   ├── 11 success
#     │       │   │   └── 14 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 13, failure: 12, success_rate: 0.520
#     │       │   │   ├── 13 success
#     │       │   │   └── 12 failure
#     │       │   └── None -> success: 12, failure: 13, success_rate: 0.480
#     │       │       ├── 12 success
#     │       │       └── 13 failure
#     │       ├── google_robot_pick_coke_can_vertically_laying -> success: 42, failure: 58, success_rate: 0.420
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 10, failure: 15, success_rate: 0.400
#     │       │   │   ├── 10 success
#     │       │   │   └── 15 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 9, failure: 16, success_rate: 0.360
#     │       │   │   ├── 9 success
#     │       │   │   └── 16 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 11, failure: 14, success_rate: 0.440
#     │       │   │   ├── 11 success
#     │       │   │   └── 14 failure
#     │       │   └── None -> success: 12, failure: 13, success_rate: 0.480
#     │       │       ├── 12 success
#     │       │       └── 13 failure
#     │       └── google_robot_pick_coke_can_standing -> success: 44, failure: 56, success_rate: 0.440
#     │           ├── recolor_cabinet_visual_matching_1 -> success: 8, failure: 17, success_rate: 0.320
#     │           │   ├── 8 success
#     │           │   └── 17 failure
#     │           ├── recolor_tabletop_visual_matching_1 -> success: 11, failure: 14, success_rate: 0.440
#     │           │   ├── 11 success
#     │           │   └── 14 failure
#     │           ├── recolor_tabletop_visual_matching_2 -> success: 13, failure: 12, success_rate: 0.520
#     │           │   ├── 13 success
#     │           │   └── 12 failure
#     │           └── None -> success: 12, failure: 13, success_rate: 0.480
#     │               ├── 12 success
#     │               └── 13 failure
#     ├── rt_1_tf_trained_for_000001120 -> success: 56, failure: 244, success_rate: 0.187
#     │   └── google_robot_pick_coke_can -> success: 56, failure: 244, success_rate: 0.187
#     │       ├── google_robot_pick_coke_can_horizontally_laying -> success: 25, failure: 75, success_rate: 0.250
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 7, failure: 18, success_rate: 0.280
#     │       │   │   ├── 7 success
#     │       │   │   └── 18 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 7, failure: 18, success_rate: 0.280
#     │       │   │   ├── 7 success
#     │       │   │   └── 18 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 6, failure: 19, success_rate: 0.240
#     │       │   │   ├── 6 success
#     │       │   │   └── 19 failure
#     │       │   └── None -> success: 5, failure: 20, success_rate: 0.200
#     │       │       ├── 5 success
#     │       │       └── 20 failure
#     │       ├── google_robot_pick_coke_can_vertically_laying -> success: 9, failure: 91, success_rate: 0.090
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 4, failure: 21, success_rate: 0.160
#     │       │   │   ├── 4 success
#     │       │   │   └── 21 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 4, failure: 21, success_rate: 0.160
#     │       │   │   ├── 4 success
#     │       │   │   └── 21 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 25, success_rate: 0.000
#     │       │   │   └── 25 failure
#     │       │   └── None -> success: 1, failure: 24, success_rate: 0.040
#     │       │       ├── 1 success
#     │       │       └── 24 failure
#     │       └── google_robot_pick_coke_can_standing -> success: 22, failure: 78, success_rate: 0.220
#     │           ├── recolor_cabinet_visual_matching_1 -> success: 2, failure: 23, success_rate: 0.080
#     │           │   ├── 2 success
#     │           │   └── 23 failure
#     │           ├── recolor_tabletop_visual_matching_1 -> success: 3, failure: 22, success_rate: 0.120
#     │           │   ├── 3 success
#     │           │   └── 22 failure
#     │           ├── recolor_tabletop_visual_matching_2 -> success: 8, failure: 17, success_rate: 0.320
#     │           │   ├── 8 success
#     │           │   └── 17 failure
#     │           └── None -> success: 9, failure: 16, success_rate: 0.360
#     │               ├── 9 success
#     │               └── 16 failure
#     ├── octo-base -> success: 3, failure: 297, success_rate: 0.010
#     │   └── google_robot_pick_coke_can -> success: 3, failure: 297, success_rate: 0.010
#     │       ├── google_robot_pick_coke_can_horizontally_laying -> success: 2, failure: 98, success_rate: 0.020
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 1, failure: 24, success_rate: 0.040
#     │       │   │   ├── 1 success
#     │       │   │   └── 24 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 1, failure: 24, success_rate: 0.040
#     │       │   │   ├── 1 success
#     │       │   │   └── 24 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 25, success_rate: 0.000
#     │       │   │   └── 25 failure
#     │       │   └── None -> success: 0, failure: 25, success_rate: 0.000
#     │       │       └── 25 failure
#     │       ├── google_robot_pick_coke_can_vertically_laying -> success: 0, failure: 100, success_rate: 0.000
#     │       │   ├── recolor_cabinet_visual_matching_1 -> success: 0, failure: 25, success_rate: 0.000
#     │       │   │   └── 25 failure
#     │       │   ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 25, success_rate: 0.000
#     │       │   │   └── 25 failure
#     │       │   ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 25, success_rate: 0.000
#     │       │   │   └── 25 failure
#     │       │   └── None -> success: 0, failure: 25, success_rate: 0.000
#     │       │       └── 25 failure
#     │       └── google_robot_pick_coke_can_standing -> success: 1, failure: 99, success_rate: 0.010
#     │           ├── recolor_cabinet_visual_matching_1 -> success: 1, failure: 24, success_rate: 0.040
#     │           │   ├── 1 success
#     │           │   └── 24 failure
#     │           ├── recolor_tabletop_visual_matching_1 -> success: 0, failure: 25, success_rate: 0.000
#     │           │   └── 25 failure
#     │           ├── recolor_tabletop_visual_matching_2 -> success: 0, failure: 25, success_rate: 0.000
#     │           │   └── 25 failure
#     │           └── None -> success: 0, failure: 25, success_rate: 0.000
#     │               └── 25 failure
#     └── openvla-7b -> success: 95, failure: 205, success_rate: 0.317
#         └── google_robot_pick_coke_can -> success: 95, failure: 205, success_rate: 0.317
#             ├── google_robot_pick_coke_can_horizontally_laying -> success: 27, failure: 73, success_rate: 0.270
#             │   ├── recolor_cabinet_visual_matching_1 -> success: 6, failure: 19, success_rate: 0.240
#             │   │   ├── 6 success
#             │   │   └── 19 failure
#             │   ├── recolor_tabletop_visual_matching_1 -> success: 2, failure: 23, success_rate: 0.080
#             │   │   ├── 2 success
#             │   │   └── 23 failure
#             │   ├── recolor_tabletop_visual_matching_2 -> success: 10, failure: 15, success_rate: 0.400
#             │   │   ├── 10 success
#             │   │   └── 15 failure
#             │   └── None -> success: 9, failure: 16, success_rate: 0.360
#             │       ├── 9 success
#             │       └── 16 failure
#             ├── google_robot_pick_coke_can_vertically_laying -> success: 16, failure: 84, success_rate: 0.160
#             │   ├── recolor_cabinet_visual_matching_1 -> success: 4, failure: 21, success_rate: 0.160
#             │   │   ├── 4 success
#             │   │   └── 21 failure
#             │   ├── recolor_tabletop_visual_matching_1 -> success: 5, failure: 20, success_rate: 0.200
#             │   │   ├── 5 success
#             │   │   └── 20 failure
#             │   ├── recolor_tabletop_visual_matching_2 -> success: 4, failure: 21, success_rate: 0.160
#             │   │   ├── 4 success
#             │   │   └── 21 failure
#             │   └── None -> success: 3, failure: 22, success_rate: 0.120
#             │       ├── 3 success
#             │       └── 22 failure
#             └── google_robot_pick_coke_can_standing -> success: 52, failure: 48, success_rate: 0.520
#                 ├── recolor_cabinet_visual_matching_1 -> success: 14, failure: 11, success_rate: 0.560
#                 │   ├── 14 success
#                 │   └── 11 failure
#                 ├── recolor_tabletop_visual_matching_1 -> success: 10, failure: 15, success_rate: 0.400
#                 │   ├── 10 success
#                 │   └── 15 failure
#                 ├── recolor_tabletop_visual_matching_2 -> success: 17, failure: 8, success_rate: 0.680
#                 │   ├── 17 success
#                 │   └── 8 failure
#                 └── None -> success: 11, failure: 14, success_rate: 0.440
#                     ├── 11 success
#                     └── 14 failure

# %% [markdown]
# ### Build Evaluation Table Based on Task Tree

# %%
import numpy as np
from scipy.stats import kruskal, pearsonr
from typing import Sequence
import pandas as pd 

def mean_maximum_rank_violation(
    perf_sim: Sequence[float], perf_real: Sequence[float]
) -> float:
    x = np.array(perf_sim)
    y = np.array(perf_real)
    assert x.shape == y.shape
    
    # pairwise comparison
    sim_comp = x[:, None] > x[None, :]
    real_comp = y[:, None] > y[None, :]
    
    mask = sim_comp != real_comp
    diff_matrix = np.abs(y[:, None] - y[None, :])
    max_rank_violations = np.max(diff_matrix * mask, axis=1)
    
    return float(np.mean(max_rank_violations))

# Extracts the results for all policies for a specific task defined by
# by pattern, assumes each policy nodes come before task nodes 
# Returns array of tuples (success_rate, total_trials)
def get_results(tree, patterns):
    nodes = [get_node(tree, [policy, *patterns]) for policy in policies]
    return np.array([[node.success_rate, node.success+node.failure] for node in nodes]) 

# Takes in a list of sublists [mean, length] 
# and generates trials for each sublist (array of 0 and 1s)
generate_trials = lambda mean_len_list: [
    np.concatenate([np.ones(int(round(m * l)), dtype=int), 
                    np.zeros(int(l - round(m * l)), dtype=int)]).tolist()
    for m, l in mean_len_list
]

n = len(policies_short)

results_df = pd.DataFrame({"Eval Setup": ["Real"] * n + ["Sim"] * n + ["Metric"] * 3, 
                        "Policy": policies_short * 2 + ["MMRV", "Pearson", "#Kruskal p<0.05"]})

results_wo_alignment_df = pd.DataFrame({"Eval Setup": ["Kitchen Counter"] * n + ["Wood Desk"] * n,
                                        "Policy": policies_short * 2,})

def evaluate_task(tree, task, compute_alignment=True, scene="Sim"):
    sim_results = get_results(tree, [task]) 

    if compute_alignment:
        real_results = np.array([[s, num_trials_per_real_task[task]] 
                             for s in REAL_PERF[task].values()])
        # Compute Statistics
        #pearson_corr = pearson_correlation(sim_results[:, 0], real_results[:, 0])
        pearson_corr = pearsonr(sim_results[:, 0], real_results[:, 0])[0]
        
        mmrv = mean_maximum_rank_violation(sim_results[:, 0], real_results[:, 0])
        # Perform the Kruskal-Wallis test for each policy
        kruskal_pvalues = np.array([
            kruskal(sim, real).pvalue if np.mean(sim) != np.mean(real) else 1
            for sim, real in zip(generate_trials(sim_results), generate_trials(real_results))
        ])
        # Count the number of policies with p-value < 0.05
        kruskal_count = np.sum(kruskal_pvalues < 0.05)

        # Store results in the Eval Results DataFrame
        results_df[task] = np.concatenate([real_results[:, 0], sim_results[:, 0], [mmrv, pearson_corr, kruskal_count]])
        
    else:
        #results_wo_alignment_df[task] = sim_results[:, 0]
        mask = results_wo_alignment_df["Eval Setup"] == scene
        results_wo_alignment_df.loc[mask, task] = sim_results[:, 0]

# %%
#Ensure tasks are in num_trials_per_real_task, and real eval results are present 
for task in ["google_robot_pick_coke_can_horizontally_laying", 
             "google_robot_pick_coke_can_vertically_laying", 
             "google_robot_pick_coke_can_standing",
             "google_robot_pick_coke_can"]:
    evaluate_task(pick_coke_can_tree, task)

for task in ["google_robot_move_near"]:
    evaluate_task(move_near_tree, task)

for task in ["google_robot_open_drawer", "google_robot_close_drawer", "google_robot_drawer_avg"]:
    evaluate_task(drawer_tree, task)

for task in ["google_robot_place_apple_in_closed_top_drawer"]:
    evaluate_task(place_apple_tree, task)

new_order = [0, 1, 3, 2, 4, 5, 6, 8, 7, 9, 10, 11, 12]
results_df = results_df.reindex(new_order)

print(results_df.to_string())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 6
#       1 #Ensure tasks are in num_trials_per_real_task, and real eval results are present
#       2 for task in ["google_robot_pick_coke_can_horizontally_laying",
#       3              "google_robot_pick_coke_can_vertically_laying",
#       4              "google_robot_pick_coke_can_standing",
#       5              "google_robot_pick_coke_can"]:
# ----> 6     evaluate_task(pick_coke_can_tree, task)
#       8 for task in ["google_robot_move_near"]:
#       9     evaluate_task(move_near_tree, task)
#
# NameError: name 'pick_coke_can_tree' is not defined

# %% [markdown]
# ### Evaluation Table For New Tasks

# %%
for task in ["google_robot_pick_coke_can_horizontally_laying", 
             "google_robot_pick_coke_can_vertically_laying", 
             "google_robot_pick_coke_can_standing",
             "google_robot_pick_coke_can"]:
    evaluate_task(pick_coke_can_tabletop_tree, task, compute_alignment=False, scene="Kitchen Counter")
    evaluate_task(pick_coke_can_wood_tree, task, compute_alignment=False, scene="Wood Desk")

#for task in ["google_robot_move_near"]:
#    evaluate_task(move_near_tabletop_tree, task, compute_alignment=False, scene="Kitchen Counter")
 #   evaluate_task(move_near_wood_tree, task, compute_alignment=False, scene="Wood Desk")

new_order = [0, 1, 3, 2, 4, 5, 6, 7, 9, 8, 10, 11]
results_wo_alignment_df = results_wo_alignment_df.reindex(new_order)

print(results_wo_alignment_df.to_string())
# Out:
#          Eval Setup          Policy  google_robot_pick_coke_can_horizontally_laying  google_robot_pick_coke_can_vertically_laying  google_robot_pick_coke_can_standing  google_robot_pick_coke_can
# 0   Kitchen Counter  rt-1-converged                                        0.640000                                          0.68                             1.000000                    0.773333
# 1   Kitchen Counter      rt-1-15pct                                        0.620000                                          0.61                             0.750000                    0.660000
# 3   Kitchen Counter      rt-1-begin                                        0.530000                                          0.29                             0.750000                    0.523333
# 2   Kitchen Counter          rt-1-x                                        0.050000                                          0.00                             0.020000                    0.023333
# 4   Kitchen Counter       octo-base                                        0.070000                                          0.08                             0.170000                    0.106667
# 5   Kitchen Counter      openvla-7b                                        0.246575                                          0.00                             0.178082                    0.158163
# 6         Wood Desk  rt-1-converged                                        0.710000                                          0.59                             0.890000                    0.730000
# 7         Wood Desk      rt-1-15pct                                        0.450000                                          0.37                             0.710000                    0.510000
# 9         Wood Desk      rt-1-begin                                        0.500000                                          0.42                             0.440000                    0.453333
# 8         Wood Desk          rt-1-x                                        0.250000                                          0.09                             0.220000                    0.186667
# 10        Wood Desk       octo-base                                        0.020000                                          0.00                             0.010000                    0.010000
# 11        Wood Desk      openvla-7b                                        0.270000                                          0.16                             0.520000                    0.316667

# %%
for task in ["google_robot_move_to_number", "google_robot_move_to_number_sum", 
             "google_robot_move_to_number_mult", "google_robot_move_to_number_smallest", 
             "google_robot_move_to_number_avg"]:
    evaluate_task(move_to_number_tree, task, compute_alignment=False, scene="Wood Desk")
    
new_order = [6, 7, 9, 8, 10, 11]
results_wo_alignment_df = results_wo_alignment_df.reindex(new_order)

print(results_wo_alignment_df.to_string())
# Out:
#    Eval Setup          Policy  google_robot_move_to_number  google_robot_move_to_number_sum  google_robot_move_to_number_mult  google_robot_move_to_number_smallest  google_robot_move_to_number_avg
# 6   Wood Desk  rt-1-converged                     0.010417                         0.000000                           0.00000                              0.000000                         0.002604
# 7   Wood Desk      rt-1-15pct                     0.000000                         0.000000                           0.00000                              0.000000                         0.000000
# 9   Wood Desk      rt-1-begin                     0.000000                         0.000000                           0.00000                              0.062500                         0.016667
# 8   Wood Desk          rt-1-x                     0.000000                         0.000000                           0.00000                              0.000000                         0.000000
# 10  Wood Desk       octo-base                     0.041667                         0.010417                           0.00000                              0.020833                         0.018229
# 11  Wood Desk      openvla-7b                     0.010417                         0.000000                           0.09375                              0.031250                         0.027344

# %% [markdown]
# ### Create Latex Result Tables

# %%
import pandas as pd

# Define the data with the new policy names and column names
data = {
    "Eval Setup": ["Sim Paper"] * 5 + ["Metric"] * 3,
    "Policy": ["rt-1-converged", "rt-1-15pct", "rt-1-x", "rt-1-begin", "octo-base", "MMRV", "Pearson", "#Kruskal p<0.05"],
    "google_robot_pick_coke_can_horizontally_laying": [0.960, 0.860, 0.820, 0.050, 0.210, 0.027, 0.981, 0],
    "google_robot_pick_coke_can_vertically_laying": [0.900, 0.790, 0.330, 0.000, 0.210, 0.027, 0.964, 0],
    "google_robot_pick_coke_can_standing": [0.710, 0.480, 0.550, 0.030, 0.090, 0.053, 0.942, 2],
    "google_robot_pick_coke_can": [0.857, 0.710, 0.567, 0.027, 0.170, 0.031, 0.976, 3],
    "google_robot_move_near": [0.442, 0.354, 0.317, 0.050, 0.042, 0.111, 0.855, 3],
    "google_robot_open_drawer": [0.601, 0.463, 0.296, 0.000, 0.009, 0.0, 0.983, 1],
    "google_robot_close_drawer": [0.861, 0.667, 0.891, 0.278, 0.444, 0.123, 0.768, 2],
    "google_robot_drawer_avg": [0.730, 0.565, 0.597, 0.139, 0.227, 0.055, 0.915, 2],
    "google_robot_place_apple_in_closed_top_drawer": [0.065, 0.130, 0.213, 0.000, 0.000, 0.0, 0.969, 0],
}

sim_paper_df = pd.DataFrame(data)
# reorder is necessary to align with resutlt order of the simulation
new_order = [0, 1, 3, 2, 4, 5, 6, 7]
sim_paper_df = sim_paper_df.reindex(new_order).reset_index(drop=True)
# Display the DataFrame
print(sim_paper_df.to_string())
# Out:
#   Eval Setup           Policy  google_robot_pick_coke_can_horizontally_laying  google_robot_pick_coke_can_vertically_laying  google_robot_pick_coke_can_standing  google_robot_pick_coke_can  google_robot_move_near  google_robot_open_drawer  google_robot_close_drawer  google_robot_drawer_avg  google_robot_place_apple_in_closed_top_drawer
# 0  Sim Paper   rt-1-converged                                           0.960                                         0.900                                0.710                       0.857                   0.442                     0.601                      0.861                    0.730                                          0.065
# 1  Sim Paper       rt-1-15pct                                           0.860                                         0.790                                0.480                       0.710                   0.354                     0.463                      0.667                    0.565                                          0.130
# 2  Sim Paper       rt-1-begin                                           0.050                                         0.000                                0.030                       0.027                   0.050                     0.000                      0.278                    0.139                                          0.000
# 3  Sim Paper           rt-1-x                                           0.820                                         0.330                                0.550                       0.567                   0.317                     0.296                      0.891                    0.597                                          0.213
# 4  Sim Paper        octo-base                                           0.210                                         0.210                                0.090                       0.170                   0.042                     0.009                      0.444                    0.227                                          0.000
# 5     Metric             MMRV                                           0.027                                         0.027                                0.053                       0.031                   0.111                     0.000                      0.123                    0.055                                          0.000
# 6     Metric          Pearson                                           0.981                                         0.964                                0.942                       0.976                   0.855                     0.983                      0.768                    0.915                                          0.969
# 7     Metric  #Kruskal p<0.05                                           0.000                                         0.000                                2.000                       3.000                   3.000                     1.000                      2.000                    2.000                                          0.000

# %%
import pandas as pd 
sim_results_df = results_df[results_df["Eval Setup"].isin(["Sim", "Metric"])].reset_index(drop=True)
#print(sim_results_df.to_string())
#print(sim_paper_df.to_string())
numeric_cols = sim_results_df.select_dtypes(include='number').columns
results_diff_df = sim_results_df.copy()
results_diff_df[numeric_cols] = sim_results_df[numeric_cols] - sim_paper_df[numeric_cols].reset_index(drop=True)
print(results_diff_df.to_string())
# Out:
#   Eval Setup           Policy
# 0        Sim   rt-1-converged
# 1        Sim       rt-1-15pct
# 2        Sim           rt-1-x
# 3        Sim       rt-1-begin
# 4        Sim        octo-base
# 5     Metric             MMRV
# 6     Metric          Pearson
# 7     Metric  #Kruskal p<0.05

# %%
task_renaming ={
    "google_robot_open_drawer": ("Open/Close Drawer", "Open"),
    "google_robot_close_drawer": ("Open/Close Drawer", "Close"),
    "google_robot_drawer_avg": ("Open/Close Drawer", "Average"),
    "google_robot_move_near": ("Move Near", "Average"),
    "google_robot_pick_coke_can_horizontally_laying": ("Pick Coke Can", "Horizontally Laying"),
    "google_robot_pick_coke_can_vertically_laying": ("Pick Coke Can", "Vertically Laying"),
    "google_robot_pick_coke_can_standing": ("Pick Coke Can", "Standing"),
    "google_robot_pick_coke_can": ("Pick Coke Can", "Average"),
    "google_robot_place_apple_in_closed_top_drawer": ("Open Top Drawer and Place Apple", "Average"),
    "google_robot_move_to_number":("Move to", "Number"),
    "google_robot_move_to_number_sum":("Move to", "Sum"),
    "google_robot_move_to_number_mult":("Move to", "Product"), 
    "google_robot_move_to_number_smallest":("Move to", "Smallest"), 
    "google_robot_move_to_number_avg": ("Move to", "Average"),
}

policy_renaming = {
        "rt-2-x": "RT-2-X",
        "rt-1-converged": "RT-1 (Converged)",
        "rt-1-15pct": "RT-1 (15\%)",
        "rt-1-begin": "RT-1 (Begin)",
        "rt-1-x": "RT-1-X",
        "octo-base": "Octo-Base",
}

def format_df(input_df, precision=3):
    df = input_df.copy()
    df = df.round(precision)
    df = df.rename(columns=task_renaming)
    df['Policy'] = df['Policy'].replace(policy_renaming)
    df = df.set_index(["Eval Setup", "Policy"])
    df.columns = pd.MultiIndex.from_tuples(df.columns)
    return df

#results_df = results_df.round(3)
#results_df['Policy'] = results_df['Policy'].replace(policy_renaming)
#results_df = results_df.set_index(["Eval Setup", "Policy"])
#results_df.columns = pd.MultiIndex.from_tuples(results_df.columns)

# %%
formatted_results_df = format_df(results_df)
display(formatted_results_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 formatted_results_df = format_df(results_df)
#       2 display(formatted_results_df)
#
# Cell In[12], line 33, in format_df(input_df)
#      31 df['Policy'] = df['Policy'].replace(policy_renaming)
#      32 df = df.set_index(["Eval Setup", "Policy"])
# ---> 33 df.columns = pd.MultiIndex.from_tuples(df.columns)
#      34 return df
#
# File /work/users/t/i/tis/mmai/.venv/lib/python3.10/site-packages/pandas/core/indexes/multi.py:222, in names_compat.<locals>.new_meth(self_or_cls, *args, **kwargs)
#     219 if "name" in kwargs:
#     220     kwargs["names"] = kwargs.pop("name")
# --> 222 return meth(self_or_cls, *args, **kwargs)
#
# File /work/users/t/i/tis/mmai/.venv/lib/python3.10/site-packages/pandas/core/indexes/multi.py:609, in MultiIndex.from_tuples(cls, tuples, sortorder, names)
#     607 if len(tuples) == 0:
#     608     if names is None:
# --> 609         raise TypeError("Cannot infer number of levels from empty list")
#     610     # error: Argument 1 to "len" has incompatible type "Hashable";
#     611     # expected "Sized"
#     612     arrays = [[]] * len(names)  # type: ignore[arg-type]
#
# TypeError: Cannot infer number of levels from empty list

# %%
formatted_results_diff_df= format_df(results_diff_df)
display(formatted_results_diff_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 formatted_results_diff_df= format_df(results_diff_df)
#       2 display(formatted_results_diff_df)
#
# NameError: name 'results_diff_df' is not defined

# %% [markdown]
# ### New Results

# %%
formatted_results_wo_alignment_df = format_df(results_wo_alignment_df, precision=4)
display(formatted_results_wo_alignment_df)
# Out:
#                             Move to
#                              Number     Sum Product Smallest Average
# Eval Setup Policy
# Wood Desk  RT-1 (Converged)  0.0104  0.0000  0.0000   0.0000  0.0026
#            RT-1 (15\%)       0.0000  0.0000  0.0000   0.0000  0.0000
#            RT-1 (Begin)      0.0000  0.0000  0.0000   0.0625  0.0167
#            RT-1-X            0.0000  0.0000  0.0000   0.0000  0.0000
#            Octo-Base         0.0417  0.0104  0.0000   0.0208  0.0182
#            openvla-7b        0.0104  0.0000  0.0938   0.0312  0.0273

# %% [markdown]
# ### Get Latex Code for Tables (Only rows with numbers can be used)

# %%
latex_results = formatted_results_df.to_latex(
    float_format=lambda x: f"{x:.3f}"
)
print(latex_results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 latex_results = formatted_results_df.to_latex(
#       2     float_format=lambda x: f"{x:.3f}"
#       3 )
#       4 print(latex_results)
#
# NameError: name 'formatted_results_df' is not defined

# %%
latex_results = formatted_results_diff_df.to_latex(
    float_format=lambda x: f"{x:.3f}"
)
print(latex_results)
# Out:
# \begin{tabular}{llrrrrrrrrr}
# \toprule
#  &  & \multicolumn{4}{r}{Pick Coke Can} & Move Near & \multicolumn{3}{r}{Open/Close Drawer} & Open Top Drawer and Place Apple \\
#  &  & Horizontally Laying & Vertically Laying & Standing & Average & Average & Open & Close & Average & Average \\
# Eval Setup & Policy &  &  &  &  &  &  &  &  &  \\
# \midrule
# \multirow[t]{5}{*}{Sim} & RT-1 (Converged) & 0.010 & -0.030 & 0.040 & 0.006 & -0.034 & -0.018 & -0.018 & -0.017 & 0.018 \\
#  & RT-1 (15\%) & 0.040 & 0.010 & 0.000 & 0.017 & 0.038 & -0.028 & 0.018 & -0.005 & 0.055 \\
#  & RT-1 (Begin) & 0.000 & 0.000 & 0.020 & 0.006 & -0.017 & 0.000 & -0.037 & -0.019 & 0.000 \\
#  & RT-1-X & 0.000 & -0.020 & 0.020 & -0.000 & 0.021 & -0.037 & 0.035 & -0.004 & 0.009 \\
#  & Octo-Base & -0.050 & 0.040 & 0.020 & 0.003 & -0.000 & 0.000 & -0.018 & -0.009 & 0.000 \\
# \cline{1-11}
# \multirow[t]{3}{*}{Metric} & MMRV & -0.011 & 0.005 & 0.011 & -0.004 & -0.111 & 0.000 & -0.019 & 0.011 & 0.000 \\
#  & Pearson & 0.003 & -0.009 & -0.040 & -0.004 & 0.015 & -0.004 & 0.100 & 0.042 & -0.048 \\
#  & #Kruskal p<0.05 & 2.000 & 1.000 & 1.000 & 1.000 & 0.000 & 3.000 & 1.000 & 1.000 & 0.000 \\
# \cline{1-11}
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Get Latex Code for New Results

# %%
latex_results = formatted_results_wo_alignment_df.to_latex(
    float_format=lambda x: f"{x:.4f}"
)
print(latex_results)
# Out:
# \begin{tabular}{llrrrrr}
# \toprule
#  &  & \multicolumn{5}{r}{Move to} \\
#  &  & Number & Sum & Product & Smallest & Average \\
# Eval Setup & Policy &  &  &  &  &  \\
# \midrule
# \multirow[t]{6}{*}{Wood Desk} & RT-1 (Converged) & 0.0104 & 0.0000 & 0.0000 & 0.0000 & 0.0026 \\
#  & RT-1 (15\%) & 0.0000 & 0.0000 & 0.0000 & 0.0000 & 0.0000 \\
#  & RT-1 (Begin) & 0.0000 & 0.0000 & 0.0000 & 0.0625 & 0.0167 \\
#  & RT-1-X & 0.0000 & 0.0000 & 0.0000 & 0.0000 & 0.0000 \\
#  & Octo-Base & 0.0417 & 0.0104 & 0.0000 & 0.0208 & 0.0182 \\
#  & openvla-7b & 0.0104 & 0.0000 & 0.0938 & 0.0312 & 0.0273 \\
# \cline{1-7}
# \bottomrule
# \end{tabular}
